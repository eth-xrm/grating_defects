# %%
# Copyright (c) 2025, ETH Zurich

# %%
import sys
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import os
import scipy.stats as stats
import scipy.ndimage
from tqdm import tqdm
import spekpy as spk
import h5py

from scipy import interpolate

# %%
rave_sim_dir = Path('../rave-sim').resolve()
simulations_dir = Path('<PATH_TO_STORE_SIMULATIONS>')
scratch_dir = simulations_dir


sys.path.insert(0, str(rave_sim_dir / "nist_lookup"))
from nist_lookup.xraydb_plugin import xray_delta_beta

# %%
sys.path.insert(0, str(rave_sim_dir / "big-wave"))
import multisim
import config
import util
import propagation

# %%
def calculate_G1_height(eng):
    # constants
    h = 6.62607004 * 10**(-34) # planck constant in mˆ2 kg / s
    c_0 = 299792458 # speed of light in m / s
    eV_to_joule = 1.602176634*10**(-19)
    N_A = 6.02214086 * 10**23 #[1/mol]
    
    lambda_ = h * c_0 / (eng*eV_to_joule)
    delta_diff = xray_delta_beta('Si', 2.34, eng)[0]
    height = np.pi  * lambda_ / (2*np.pi * delta_diff)

    return height


def signal_retrieval_least_squares(data, period=None, axis=-1):
    if axis != -1:
        data = np.moveaxis(data, axis, -1)

    nsteps = data.shape[-1]

    if period is None:
        period = nsteps

    phi = np.linspace(0, 2 * np.pi * nsteps / (period), nsteps, endpoint=False)
    M = np.c_[np.sin(phi), np.cos(phi), np.ones(nsteps)]
    res, chi2, _rank, _sing_vals = np.linalg.lstsq(M, data.reshape((-1, nsteps)).T, rcond=-1)

    res = res.T.reshape((*data.shape[:-1], -1))

    dabs = res[...,2]
    dphase = -np.arctan2(res[...,0], res[...,1])
    dvis = np.sqrt(res[...,0]**2 + res[...,1]**2) / dabs

    # normalization to the total number of counts
    dabs *= nsteps

    return dabs, dphase, dvis, np.nanmean(chi2)


def calculate_pixel_intensity(x, fringe, pxEdges, statistics = 'sum'):
    fringeStats = stats.binned_statistic(x, fringe, bins=pxEdges, statistic = statistics)
    return fringeStats.statistic

def perform_binned_signal_retrieval(x, wf, pxSize, nrSteps, plot_curve = True):
    leftSide = np.arange(0-pxSize/2, np.min(x), -pxSize)
    rightSide = np.arange(0 + pxSize/2, np.max(x), pxSize)
    pxEdges = np.concatenate([np.flip(leftSide), rightSide])
    int_px = []
    for i in range(nrSteps):
        int_px.append(calculate_pixel_intensity(x, wf[i,:], pxEdges))
    int_px = np.asarray(int_px)

    trans, phase, vis, _ = signal_retrieval_least_squares(int_px, period = nrSteps, axis = 0)
    if plot_curve:
        plot_curves(trans, phase, vis, pxEdges)
    return int_px, trans, phase, vis, pxEdges

def plot_curves(trans, phase, vis, pxEdges):

    fig, axs = plt.subplots(figsize=(15,6), sharex = True, nrows = 1, ncols = 2)
    axs[0].plot(pxEdges[1:], trans, label = 'Transmission')
    axs[0].set_title('Transmission')
    axs[1].plot(pxEdges[1:], vis, label = 'Visibility')
    axs[1].set_title('Visibility')

def perform_binning(x, wf, pxSize):
    leftSide = np.arange(0-pxSize/2, np.min(x), -pxSize)
    rightSide = np.arange(0 + pxSize/2, np.max(x), pxSize)
    pxEdges = np.concatenate([np.flip(leftSide), rightSide])
    int_px = calculate_pixel_intensity(x, wf, pxEdges, statistics = 'mean')
    return int_px


    #np.random.seed(1)
    
    sample_energy = np.random.choice(x, p=y)
    if sample_energy >= low_threshold:
        return True
    else:
        return False
    
    
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

def calculate_SNR(wavefronts, detector_x, phase_steps):
    summed_wf = np.zeros_like(wavefronts[0][0])
        
    for point in wavefronts:
        wf, x_point, eng = point
        
        summed_wf += wf

    return summed_wf

def get_subdict(dict_, idx):
    sub_dict = {}
    for key in dict_.keys():
        sub_dict[key] = dict_[key][idx]
    return sub_dict

def calc_Vis_theoretical(eng, Edes,m):
    V = 2/np.pi * np.abs(np.sin(np.pi / 2 * Edes / eng)**2 * np.sin(m * np.pi / 2 * Edes / eng))
    return V

def mu_h2o(eng):
    lambda_ = h * c_0 / (eng*eV_to_joule)
    beta = xray_delta_beta('H2O', 1.0, eng)[1]
    return 4 * np.pi / lambda_ * beta

# %%
# constants
h = 6.62607004 * 10**(-34) # planck constant in mˆ2 kg / s
c_0 = 299792458 # speed of light in m / s
eV_to_joule = 1.602176634*10**(-19)
N_A = 6.02214086 * 10**23 #[1/mol]
E_des = 46000

lambda_ = h * c_0 / (E_des*eV_to_joule)
p2 = 4.2*10**(-6)
p0 = p1 = p2

Dn_3 = 3*p2**2/(2*lambda_) / 2
print(Dn_3)

z_g0 = 0.218
z_g1 = z_g0 + Dn_3
z_g2 = z_g0 + 2*Dn_3
z_detector = z_g2 + 0.01

h2 = 180e-6
h1 = 59e-6 

dc0 = [0.5, 0.5]
dc2 = [0.24, 0.52]

print("Z0: ", z_g0)
print("Z1: ", z_g1)
print("Z2: ", z_g2)
print("Z Detector: ", z_detector)

print(Dn_3)
# Out:
# 0.49085288108789216
# Z0:  0.218
# Z1:  0.7088528810878921
# Z2:  1.1997057621757843
# Z Detector:  1.2097057621757843
# 0.49085288108789216

# %%
2200/ 4200
# Out:
# 0.5238095238095238

# %%
N = 2**26
max_energy = 70000
dx = propagation.max_dx(z_g0, 10e-6, N, propagation.convert_energy_wavelength(max_energy))

# %% [markdown]
# # Now with both gratings modelled

# %%
meta_data_g0 = np.load('../grating_models/DRIE_models/mask_g0_different_dc_2.npz')
meta_data_g2 = np.load('../grating_models/DRIE_models/mask_g2_different_dc_2.npz')



grid_path_g0 = os.path.abspath('../grating_models/DRIE_models/mask_g0_different_dc_2.npy')
grid_path_g2 = os.path.abspath('../grating_models/DRIE_models/mask_g2_different_dc_2.npy')


dx_g0 = meta_data_g0['x'][1].item()-meta_data_g0['x'][0].item()
dz_g0 = meta_data_g0['z'].item()

dx_g2 = meta_data_g2['x'][1].item()-meta_data_g2['x'][0].item()
dz_g2 = meta_data_g2['z'].item()

# %%
s = spk.Spek(kvp=70, dk = 0.1, th = 10) # Create a spectrum
s.multi_filter((('Be', 0.15), ('Al', 3))) # Create a spectrum
k, f = s.get_spectrum(edges=True) # Get the spectrum

energyRange = [4000, 70000]
dE = 100
filtering = 0.000

energies = np.arange(5, 70+0.1, 0.1)*1e3


tube_spectrum_txt = interpolate.interp1d(k*1e3, f, fill_value = 'extrapolate')
spec_txt = tube_spectrum_txt(energies)

with h5py.File('../spectra/spectrum_70_spekpy_filtered_3mmAl.h5', 'w') as h5:
    h5.create_dataset('pdf', data =  spec_txt/ np.sum(spec_txt))
    h5.create_dataset('energy', data = energies)

path_to_spectrum = os.path.abspath('../spectra/spectrum_70_spekpy_filtered_3mmAl.h5')

# %%
config_dict = {
        "sim_params": {
            "N": N,
            "dx": dx,
            "z_detector": z_g2 + 500e-6,
            "detector_size": 0.004,
            "detector_pixel_size_x": 1e-7,
            "detector_pixel_size_y": 1.0,
            "chunk_size": 256 * 1024 * 1024 // 16,  # use 256MB chunks
        },
        "use_disk_vector": False,
        "save_final_u_vectors": False,
        "dtype": "c8",
        "multisource": {
            "type": "points",
            "energy_range": [11000, 70000],
            "x_range": [-10e-6, 10e-6],
            "z": 0.0,
            "nr_source_points": 1000,
            "seed": 1,
            "spectrum": path_to_spectrum,
        },
        "elements": [
            {
                "type": "sample",
                "z_start": z_g0,
                "pixel_size_x": dx_g0,
                "pixel_size_z": dz_g0,
                "grid_path": grid_path_g0,
                "materials": [["Au", 19.32], ["Si", 2.34]],
                "x_positions": [0.0],
            },
            {
                "type": "grating",
                "pitch": p0,
                "dc": [1.0, 1.0],
                "z_start": z_g0 + 117e-6,
                "thickness": 1e-8,
                "nr_steps": 0,
                "x_positions": [0.0],
                "substrate_thickness": 370*1e-6 - 117e-6 - 1e-8,
                "mat_a": ["Si", 2.34],
                "mat_b": ["Si", 2.34],
                "mat_substrate": ["Si", 2.34],
            },
            {
                "type": "grating",
                "pitch": p1,
                "dc": [0.5, 0.5],
                "z_start": z_g1,
                "thickness": h1,
                "nr_steps": 10,
                "x_positions": [0.0],
                "substrate_thickness": 200 * 1e-6 - h1,
                "mat_a": ["Si", 2.34],
                "mat_b": None,
                "mat_substrate": ["Si", 2.34],
            },
            {
                "type": "grating",
                "pitch": p2,
                "dc": [0.5, 0.5],
                "z_start": z_g2,
                "thickness": h2,
                "nr_steps": 40,
                "x_positions": (np.arange(5) * p2/5).tolist(),
                "substrate_thickness": 500*1e-6 - h2,
                "mat_a": ["C5H8O2", 1.19],
                "mat_b": ["Au", 19.32],
                "mat_substrate": ["C", 2.26],
            },
        ],
}

sim_path = multisim.setup_simulation(config_dict, Path("."), simulations_dir)
# Out:
# 2024-03-25 20:42:57,620 INFO: Setting up simulation
# 2024-03-25 20:44:00,926 INFO: Finished setting up simulation in /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140

# %%
for i in range(1000):
    os.system(f"CUDA_VISIBLE_DEVICES=0 ../rave-sim/fast-wave/build-Release/fastwave -s {i} {sim_path}")
# Out:
# [2024-03-25 20:44:22.429] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000000
# [2024-03-25 20:44:22.897] [info] Simulating optical element 1/4
# [2024-03-25 20:44:28.249] [info] Elapsed time for optical element: 5352.0283 ms
# [2024-03-25 20:44:28.249] [info] Simulating optical element 2/4
# [2024-03-25 20:44:28.272] [info] Elapsed time for optical element: 22.947552 ms
# [2024-03-25 20:44:28.293] [info] Simulating optical element 3/4
# [2024-03-25 20:44:28.569] [info] Elapsed time for optical element: 275.72012 ms
# [2024-03-25 20:44:28.593] [info] Simulating optical element 4/4
# [2024-03-25 20:44:29.623] [info] Elapsed time for optical element: 1030.6805 ms
# [2024-03-25 20:44:29.624] [info] Running phase step 2/5
# [2024-03-25 20:44:29.626] [info] Simulating optical element 4/4
# [2024-03-25 20:44:30.658] [info] Elapsed time for optical element: 1031.6042 ms
# [2024-03-25 20:44:30.659] [info] Running phase step 3/5
# [2024-03-25 20:44:30.661] [info] Simulating optical element 4/4
# [2024-03-25 20:44:31.693] [info] Elapsed time for optical element: 1032.0134 ms
# [2024-03-25 20:44:31.694] [info] Running phase step 4/5
# [2024-03-25 20:44:31.696] [info] Simulating optical element 4/4
# [2024-03-25 20:44:32.728] [info] Elapsed time for optical element: 1031.5035 ms
# [2024-03-25 20:44:32.729] [info] Running phase step 5/5
# [2024-03-25 20:44:32.729] [info] Simulating optical element 4/4
# [2024-03-25 20:44:33.758] [info] Elapsed time for optical element: 1028.4152 ms
# [2024-03-25 20:44:33.759] [info] Simulation finished in 11.329629966 seconds
# [2024-03-25 20:44:34.045] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000001
# [2024-03-25 20:44:34.431] [info] Simulating optical element 1/4
# [2024-03-25 20:44:39.708] [info] Elapsed time for optical element: 5276.776 ms
# [2024-03-25 20:44:39.708] [info] Simulating optical element 2/4
# [2024-03-25 20:44:39.731] [info] Elapsed time for optical element: 23.259872 ms
# [2024-03-25 20:44:39.752] [info] Simulating optical element 3/4
# [2024-03-25 20:44:40.032] [info] Elapsed time for optical element: 280.2688 ms
# [2024-03-25 20:44:40.057] [info] Simulating optical element 4/4
# [2024-03-25 20:44:41.105] [info] Elapsed time for optical element: 1048.2267 ms
# [2024-03-25 20:44:41.106] [info] Running phase step 2/5
# [2024-03-25 20:44:41.108] [info] Simulating optical element 4/4
# [2024-03-25 20:44:42.156] [info] Elapsed time for optical element: 1048.0123 ms
# [2024-03-25 20:44:42.157] [info] Running phase step 3/5
# [2024-03-25 20:44:42.159] [info] Simulating optical element 4/4
# [2024-03-25 20:44:43.207] [info] Elapsed time for optical element: 1047.9557 ms
# [2024-03-25 20:44:43.208] [info] Running phase step 4/5
# [2024-03-25 20:44:43.210] [info] Simulating optical element 4/4
# [2024-03-25 20:44:44.258] [info] Elapsed time for optical element: 1047.7219 ms
# [2024-03-25 20:44:44.259] [info] Running phase step 5/5
# [2024-03-25 20:44:44.259] [info] Simulating optical element 4/4
# [2024-03-25 20:44:45.306] [info] Elapsed time for optical element: 1046.5785 ms
# [2024-03-25 20:44:45.308] [info] Simulation finished in 11.261591265 seconds
# [2024-03-25 20:44:45.612] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20
[info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000016
# [2024-03-25 20:47:30.019] [info] Simulating optical element 1/4
# [2024-03-25 20:47:35.618] [info] Elapsed time for optical element: 5599.613 ms
# [2024-03-25 20:47:35.618] [info] Simulating optical element 2/4
# [2024-03-25 20:47:35.642] [info] Elapsed time for optical element: 23.25344 ms
# [2024-03-25 20:47:35.663] [info] Simulating optical element 3/4
# [2024-03-25 20:47:35.946] [info] Elapsed time for optical element: 282.8124 ms
# [2024-03-25 20:47:35.970] [info] Simulating optical element 4/4
# [2024-03-25 20:47:37.030] [info] Elapsed time for optical element: 1059.3235 ms
# [2024-03-25 20:47:37.031] [info] Running phase step 2/5
# [2024-03-25 20:47:37.033] [info] Simulating optical element 4/4
# [2024-03-25 20:47:38.093] [info] Elapsed time for optical element: 1059.8707 ms
# [2024-03-25 20:47:38.094] [info] Running phase step 3/5
# [2024-03-25 20:47:38.096] [info] Simulating optical element 4/4
# [2024-03-25 20:47:39.155] [info] Elapsed time for optical element: 1059.4379 ms
# [2024-03-25 20:47:39.156] [info] Running phase step 4/5
# [2024-03-25 20:47:39.158] [info] Simulating optical element 4/4
# [2024-03-25 20:47:40.217] [info] Elapsed time for optical element: 1059.2527 ms
# [2024-03-25 20:47:40.219] [info] Running phase step 5/5
# [2024-03-25 20:47:40.219] [info] Simulating optical element 4/4
# [2024-03-25 20:47:41.277] [info] Elapsed time for optical element: 1058.1406 ms
# [2024-03-25 20:47:41.279] [info] Simulation finished in 11.697047824 seconds
# [2024-03-25 20:47:41.558] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000017
# [2024-03-25 20:47:41.985] [info] Simulating optical element 1/4
# [2024-03-25 20:47:47.598] [info] Elapsed time for optical element: 5612.7607 ms
# [2024-03-25 20:47:47.598] [info] Simulating optical element 2/4
# [2024-03-25 20:47:47.621] [info] Elapsed time for optical element: 23.253504 ms
# [2024-03-25 20:47:47.642] [info] Simulating optical element 3/4
# [2024-03-25 20:47:47.927] [info] Elapsed time for optical element: 284.64743 ms
# [2024-03-25 20:47:47.951] [info] Simulating optical element 4/4
# [2024-03-25 20:47:49.018] [info] Elapsed time for optical element: 1066.6964 ms
# [2024-03-25 20:47:49.019] [info] Running phase step 2/5
# [2024-03-25 20:47:49.021] [info] Simulating optical element 4/4
# [2024-03-25 20:47:50.090] [info] Elapsed time for optical element: 1068.5588 ms
# [2024-03-25 20:47:50.091] [info] Running phase step 3/5
# [2024-03-25 20:47:50.093] [info] Simulating optical element 4/4
# [2024-03-25 20:47:51.163] [info] Elapsed time for optical element: 1069.888 ms
# [2024-03-25 20:47:51.164] [info] Running phase step 4/5
# [2024-03-25 20:47:51.166] [info] Simulating optical element 4/4
# [2024-03-25 20:47:52.236] [info] Elapsed time for optical element: 1070.3783 ms
# [2024-03-25 20:47:52.238] [info] Running phase step 5/5
# [2024-03-25 20:47:52.238] [info] Simulating optical element 4/4
# [2024-03-25 20:47:53.307] [info] Elapsed time for optical element: 1069.6501 ms
# [2024-03-25 20:47:53.309] [info] Simulation finished in 11.750206434 seconds
# [2024-03-25 20:47:53.606] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000018
# [2024-03-25 20:47:54.028] [info] Simulating optical element 1/4
# [2024-03-25 20:47:59.615] [info] Elapsed time for optical element: 5586.5435 ms
# [2024-03-25 20:47:59.615] [info] Simulating optical element 2/4
# [2024-03-25 20:47:59.638] [info] Elapsed time for optical element: 23.040192 ms
# [2024-03-25 20:47:59.659] [info] Simulating optical element 3/4
# [2024-03-25 20:47:59.939] [info] Elapsed time for optical element: 280.04532 ms
# [2024-03-25 20:47:59.963] [info] Simulating optical element 4/4
# [2024-03-25 20:48:01.013] [info] Elapsed time for optical element: 1049.6613 ms
# [2024-03-25 20:48:01.014] [info] Running phase step 2/5
# [2024-03-25 20:48:01.016] [info] Simulating optical element 4/4
# [2024-03-25 20:48:02.068] [info] Elapsed time for optical element: 1051.7461 ms
# [2024-03-25 20:48:02.069] [info] Running phase step 3/5
# [2024-03-25 20:48:02.071] [info] Simulating optical element 4/4
# [2024-03-25 20:48:03.122] [info] Elapsed time for optical element: 1051.4204 ms
# [2024-03-25 20:48:03.123] [info] Running phase step 4/5
# [2024-03-25 20:48:03.125] [info] Simulating optical element 4/4
# [2024-03-25 20:48:04.178] [info] Elapsed time for optical element: 1052.7526 ms
# [2024-03-25 20:48:04.179] [info] Running phase step 5/5
# [2024-03-25 20:48:04.179] [info] Simulating optical element 4/4
# [2024-03-25 20:48:05.229] [info] Elapsed time for optical element: 1049.3899 ms
# [2024-03-25 20:48:05.238] [info] Simulation finished in 11.631191521 seconds
# [2024-03-25 20:48:05.531] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000019
# [2024-03-25 20:48:05.954] [info] Simulating optical element 1/4
# [2024-03-25 20:48:11.548] [info] Elapsed time for optical element: 5594.797 ms
# [2024-03-25 20:48:11.548] [info] Simulating optical element 2/4
# [2024-03-25 20:48:11.572] [info] Elapsed time for optical element: 23.126465 ms
# [2024-03-25 20:48:11.593] [info] Simulating optical element 3/4
# [2024-03-25 20:48:11.876] [info] Elapsed time for optical element: 282.99435 ms
# [2024-03-25 20:48:11.900] [info] Simulating optical element 4/4
# [2024-03-25 20:48:12.957] [info] Elapsed time for optical element: 1056.8265 ms
# [2024-03-25 20:48:12.958] [info] Running phase step 2/5
# [2024-03-25 20:48:12.960] [info] Simulating optical element 4/4
# [2024-03-25 20:48:14.017] [info] Elapsed time for optical element: 1057.2667 ms
# [2024-03-25 20:48:14.018] [info] Running phase step 3/5
# [2024-03-25 20:48:14.020] [info] Simulating optical element 4/4
# [2024-03-25 20:48:15.080] [info] Elapsed time for optical element: 1059.9791 ms
# [2024-03-25 20:48:15.081] [info] Running phase step 4/5
# [2024-03-25 20:48:15.083] [info] Simulating optical element 4/4
# [2024-03-25 20:48:16.146] [info] Elapsed time for optical element: 1062.3098 ms
# [2024-03-25 20:48:16.147] [info] Running phase step 5/5
# [2024-03-25 20:48:16.147] [info] Simulating optical element 4/4
# [2024-03-25 20:48:17.203] [info] Elapsed time for optical element: 1056.353 ms
# [2024-03-25 20:48:17.205] [info] Simulation finished in 11.673703133 seconds
# [2024-03-25 20:48:17.507] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000020
# [2024-03-25 20:48:17.935] [info] Simulating optical element 1/4
# [2024-03-25 20:48:23.595] [info] Elapsed time for optical element: 5660.654 ms
# [2024-03-25 20:48:23.596] [info] Simulating optical element 2/4
# [2024-03-25 20:48:23.619] [info] Elapsed time for optical element: 23.447552 ms
# [2024-03-25 20:48:23.640] [info] Simulating optical element 3/4
# [2024-03-25 20:48:23.933] [info] Elapsed time for optical element: 292.23746 ms
# [2024-03-25 20:48:23.958] [info] Simulating optical element 4/4
# [2024-03-25 20:48:25.055] [info] Elapsed time for optical element: 1097.4144 ms
# [2024-03-25 20:48:25.056] [info] Running phase step 2/5
# [2024-03-25 20:48:25.058] [info] Simulating optical element 4/4
# [2024-03-25 20:48:26.155] [info] Elapsed time for optical element: 1096.8372 ms
# [2024-03-25 20:48:26.156] [info] Running phase step 3/5
# [2024-03-25 20:48:26.158] [info] Simulating optical element 4/4
# [2024-03-25 20:48:27.256] [info] Elapsed time for optical element: 1097.2009 ms
# [2024-03-25 20:48:27.257] [info] Running phase step 4/5
# [2024-03-25 20:48:27.259] [info] Simulating optical element 4/4
# [2024-03-25 20:48:28.357] [info] Elapsed time for optical element: 1098.18 ms
# [2024-03-25 20:48:28.358] [info] Running phase step 5/5
# [2024-03-25 20:48:28.358] [info] Simulating optical element 4/4
# [2024-03-25 20:48:29.454] [info] Elapsed time for optical element: 1095.6863 ms
# [2024-03-25 20:48:29.456] [info] Simulation finished in 11.947198237 seconds
# [2024-03-25 20:48:29.757] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000021
# [2024-03-25 20:48:30.160] [info] Simulating optical element 1/4
# [2024-03-25 20:48:35.871] [info] Elapsed time for optical element: 5710.2637 ms
# [2024-03-25 20:48:35.871] [info] Simulating optical element 2/4
# [2024-03-25 20:48:35.894] [info] Elapsed time for optical element: 23.732224 ms
# [2024-03-25 20:48:35.916] [info] Simulating optical element 3/4
# [2024-03-25 20:48:36.214] [info] Elapsed time for optical element: 297.692 ms
# [2024-03-25 20:48:36.239] [info] Simulating optical element 4/4
# [2024-03-25 20:48:37.357] [info] Elapsed time for optical element: 1117.5015 ms
# [2024-03-25 20:48:37.358] [info] Running phase step 2/5
# [2024-03-25 20:48:37.360] [info] Simulating optical element 4/4
# [2024-03-25 20:48:38.480] [info] Elapsed time for optical element: 1119.7727 ms
# [2024-03-25 20:48:38.481] [info] Running phase step 3/5
# [2024-03-25 20:48:38.483] [info] Simulating optical element 4/4
# [2024-03-25 20:48:39.603] [info] Elapsed time for optical element: 1120.4567 ms
# [2024-03-25 20:48:39.604] [info] Running phase step 4/5
# [2024-03-25 20:48:39.606] [info] Simulating optical element 4/4
# [2024-03-25 20:48:40.725] [info] Elapsed time for optical element: 1118.7755 ms
# [2024-03-25 20:48:40.726] [info] Running phase step 5/5
# [2024-03-25 20:48:40.726] [info] Simulating optical element 4/4
# [2024-03-25 20:48:41.843] [info] Elapsed time for optical element: 1116.3507 ms
# [2024-03-25 20:48:41.845] [info] Simulation finished in 12.086807035 seconds
# [2024-03-25 20:48:42.134] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000022
# [2024-03-25 20:48:42.577] [info] Simulating optical element 1/4
# [2024-03-25 20:48:48.263] [info] Elapsed time for optical element: 5685.3506 ms
# [2024-03-25 20:48:48.263] [info] Simulating optical element 2/4
# [2024-03-25 20:48:48.286] [info] Elapsed time for optical element: 23.25712 ms
# [2024-03-25 20:48:48.307] [info] Simulating optical element 3/4
# [2024-03-25 20:48:48.594] [info] Elapsed time for optical element: 286.58426 ms
# [2024-03-25 20:48:48.619] [info] Simulating optical element 4/4
# [2024-03-25 20:48:49.693] [info] Elapsed time for optical element: 1074.1914 ms
# [2024-03-25 20:48:49.694] [info] Running phase step 2/5
# [2024-03-25 20:48:49.696] [info] Simulating optical element 4/4
# [2024-03-25 20:48:50.769] [info] Elapsed time for optical element: 1072.3922 ms
# [2024-03-25 20:48:50.770] [info] Running phase step 3/5
# [2024-03-25 20:48:50.772] [info] Simulating optical element 4/4
# [2024-03-25 20:48:51.850] [info] Elapsed time for optical element: 1078.8086 ms
# [2024-03-25 20:48:51.852] [info] Running phase step 4/5
# [2024-03-25 20:48:51.854] [info] Simulating optical element 4/4
# [2024-03-25 20:48:52.931] [info] Elapsed time for optical element: 1077.7661 ms
# [2024-03-25 20:48:52.933] [info] Running phase step 5/5
# [2024-03-25 20:48:52.933] [info] Simulating optical element 4/4
# [2024-03-25 20:48:54.006] [info] Elapsed time for optical element: 1073.7869 ms
# [2024-03-25 20:48:54.008] [info] Simulation finished in 11.873203114 seconds
# [2024-03-25 20:48:54.282] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000023
# [2024-03-25 20:48:54.703] [info] Simulating optical element 1/4
# [2024-03-25 20:49:00.431] [info] Elapsed time for optical element: 5728.2275 ms
# [2024-03-25 20:49:00.431] [info] Simulating optical element 2/4
# [2024-03-25 20:49:00.455] [info] Elapsed time for optical element: 23.535904 ms
# [2024-03-25 20:49:00.476] [info] Simulating optical element 3/4
# [2024-03-25 20:49:00.771] [info] Elapsed time for optical element: 294.21494 ms
# [2024-03-25 20:49:00.796] [info] Simulating optical element 4/4
# [2024-03-25 20:49:01.894] [info] Elapsed time for optical element: 1098.0946 ms
# [2024-03-25 20:49:01.895] [info] Running phase step 2/5
# [2024-03-25 20:49:01.897] [info] Simulating optical element 4/4
# [2024-03-25 20:49:03.002] [info] Elapsed time for optical element: 1104.774 ms
# [2024-03-25 20:49:03.003] [info] Running phase step 3/5
# [2024-03-25 20:49:03.005] [info] Simulating optical element 4/4
# [2024-03-25 20:49:04.108] [info] Elapsed time for optical element: 1102.6261 ms
# [2024-03-25 20:49:04.109] [info] Running phase step 4/5
# [2024-03-25 20:49:04.111] [info] Simulating optical element 4/4
# [2024-03-25 20:49:05.214] [info] Elapsed time for optical element: 1103.4255 ms
# [2024-03-25 20:49:05.215] [info] Running phase step 5/5
# [2024-03-25 20:49:05.215] [info] Simulating optical element 4/4
# [2024-03-25 20:49:06.317] [info] Elapsed time for optical element: 1101.5579 ms
# [2024-03-25 20:49:06.319] [info] Simulation finished in 12.0355127 seconds
# [2024-03-25 20:49:06.616] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000024
# [2024-03-25 20:49:07.040] [info] Simulating optical element 1/4
# [2024-03-25 20:49:12.801] [info] Elapsed time for optical element: 5760.9556 ms
# [2024-03-25 20:49:12.801] [info] Simulating optical element 2/4
# [2024-03-25 20:49:12.825] [info] Elapsed time for optical element: 23.491552 ms
# [2024-03-25 20:49:12.846] [info] Simulating optical element 3/4
# [2024-03-25 20:49:13.145] [info] Elapsed time for optical element: 298.77026 ms
# [2024-03-25 20:49:13.170] [info] Simulating optical element 4/4
# [2024-03-25 20:49:14.288] [info] Elapsed time for optical element: 1117.7968 ms
# [2024-03-25 20:49:14.289] [info] Running phase step 2/5
# [2024-03-25 20:49:14.291] [info] Simulating optical element 4/4
# [2024-03-25 20:49:15.407] [info] Elapsed time for optical element: 1115.5123 ms
# [2024-03-25 20:49:15.408] [info] Running phase step 3/5
# [2024-03-25 20:49:15.410] [info] Simulating optical element 4/4
# [2024-03-25 20:49:16.530] [info] Elapsed time for optical element: 1119.3259 ms
# [2024-03-25 20:49:16.531] [info] Running phase step 4/5
# [2024-03-25 20:49:16.533] [info] Simulating optical element 4/4
# [2024-03-25 20:49:17.652] [info] Elapsed time for optical element: 1118.9672 ms
# [2024-03-25 20:49:17.653] [info] Running phase step 5/5
# [2024-03-25 20:49:17.653] [info] Simulating optical element 4/4
# [2024-03-25 20:49:18.771] [info] Elapsed time for optical element: 1117.984 ms
# [2024-03-25 20:49:18.773] [info] Simulation finished in 12.156078301 seconds
# [2024-03-25 20:49:19.064] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000025
# [2024-03-25 20:49:19.483] [info] Simulating optical element 1/4
# [2024-03-25 20:49:25.266] [info] Elapsed time for optical element: 5782.679 ms
# [2024-03-25 20:49:25.266] [info] Simulating optical element 2/4
# [2024-03-25 20:49:25.290] [info] Elapsed time for optical element: 23.400736 ms
# [2024-03-25 20:49:25.311] [info] Simulating optical element 3/4
# [2024-03-25 20:49:25.606] [info] Elapsed time for optical element: 294.64917 ms
# [2024-03-25 20:49:25.631] [info] Simulating optical element 4/4
# [2024-03-25 20:49:26.756] [info] Elapsed time for optical element: 1124.6367 ms
# [2024-03-25 20:49:26.757] [info] Running phase step 2/5
# [2024-03-25 20:49:26.759] [info] Simulating optical element 4/4
# [2024-03-25 20:49:27.886] [info] Elapsed time for optical element: 1126.3036 ms
# [2024-03-25 20:49:27.887] [info] Running phase step 3/5
# [2024-03-25 20:49:27.889] [info] Simulating optical element 4/4
# [2024-03-25 20:49:29.016] [info] Elapsed time for optical element: 1126.8308 ms
# [2024-03-25 20:49:29.017] [info] Running phase step 4/5
# [2024-03-25 20:49:29.019] [info] Simulating optical element 4/4
# [2024-03-25 20:49:30.146] [info] Elapsed time for optical element: 1127.012 ms
# [2024-03-25 20:49:30.147] [info] Running phase step 5/5
# [2024-03-25 20:49:30.147] [info] Simulating optical element 4/4
# [2024-03-25 20:49:31.270] [info] Elapsed time for optical element: 1123.33 ms
# [2024-03-25 20:49:31.272] [info] Simulation finished in 12.207635667 seconds
# [2024-03-25 20:49:31.568] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000026
# [2024-03-25 20:49:31.994] [info] Simulating optical element 1/4
# [2024-03-25 20:49:37.758] [info] Elapsed time for optical element: 5764.218 ms
# [2024-03-25 20:49:37.758] [info] Simulating optical element 2/4
# [2024-03-25 20:49:37.782] [info] Elapsed time for optical element: 23.433664 ms
# [2024-03-25 20:49:37.803] [info] Simulating optical element 3/4
# [2024-03-25 20:49:38.090] [info] Elapsed time for optical element: 286.44336 ms
# [2024-03-25 20:49:38.114] [info] Simulating optical element 4/4
# [2024-03-25 20:49:39.193] [info] Elapsed time for optical element: 1078.4559 ms
# [2024-03-25 20:49:39.194] [info] Running phase step 2/5
# [2024-03-25 20:49:39.196] [info] Simulating optical element 4/4
# [2024-03-25 20:49:40.271] [info] Elapsed time for optical element: 1075.4557 ms
# [2024-03-25 20:49:40.272] [info] Running phase step 3/5
# [2024-03-25 20:49:40.274] [info] Simulating optical element 4/4
# [2024-03-25 20:49:41.354] [info] Elapsed time for optical element: 1079.3295 ms
# [2024-03-25 20:49:41.355] [info] Running phase step 4/5
# [2024-03-25 20:49:41.357] [info] Simulating optical element 4/4
# [2024-03-25 20:49:42.434] [info] Elapsed time for optical element: 1077.5364 ms
# [2024-03-25 20:49:42.436] [info] Running phase step 5/5
# [2024-03-25 20:49:42.436] [info] Simulating optical element 4/4
# [2024-03-25 20:49:43.508] [info] Elapsed time for optical element: 1072.2804 ms
# [2024-03-25 20:49:43.510] [info] Simulation finished in 11.941334502 seconds
# [2024-03-25 20:49:43.807] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000027
# [2024-03-25 20:49:44.236] [info] Simulating optical element 1/4
# [2024-03-25 20:49:50.002] [info] Elapsed time for optical element: 5766.1606 ms
# [2024-03-25 20:49:50.002] [info] Simulating optical element 2/4
# [2024-03-25 20:49:50.025] [info] Elapsed time for optical element: 23.182625 ms
# [2024-03-25 20:49:50.046] [info] Simulating optical element 3/4
# [2024-03-25 20:49:50.331] [info] Elapsed time for optical element: 284.94446 ms
# [2024-03-25 20:49:50.355] [info] Simulating optical element 4/4
# [2024-03-25 20:49:51.429] [info] Elapsed time for optical element: 1073.3397 ms
# [2024-03-25 20:49:51.430] [info] Running phase step 2/5
# [2024-03-25 20:49:51.432] [info] Simulating optical element 4/4
# [2024-03-25 20:49:52.504] [info] Elapsed time for optical element: 1071.8822 ms
# [2024-03-25 20:49:52.505] [info] Running phase step 3/5
# [2024-03-25 20:49:52.507] [info] Simulating optical element 4/4
# [2024-03-25 20:49:53.579] [info] Elapsed time for optical element: 1072.3566 ms
# [2024-03-25 20:49:53.581] [info] Running phase step 4/5
# [2024-03-25 20:49:53.583] [info] Simulating optical element 4/4
# [2024-03-25 20:49:54.656] [info] Elapsed time for optical element: 1073.8079 ms
# [2024-03-25 20:49:54.658] [info] Running phase step 5/5
# [2024-03-25 20:49:54.658] [info] Simulating optical element 4/4
# [2024-03-25 20:49:55.728] [info] Elapsed time for optical element: 1070.7852 ms
# [2024-03-25 20:49:55.730] [info] Simulation finished in 11.922189367 seconds
# [2024-03-25 20:49:56.024] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000028
# [2024-03-25 20:49:56.451] [info] Simulating optical element 1/4
# [2024-03-25 20:50:02.249] [info] Elapsed time for optical element: 5798.7153 ms
# [2024-03-25 20:50:02.249] [info] Simulating optical element 2/4
# [2024-03-25 20:50:02.272] [info] Elapsed time for optical element: 23.072609 ms
# [2024-03-25 20:50:02.294] [info] Simulating optical element 3/4
# [2024-03-25 20:50:02.574] [info] Elapsed time for optical element: 280.37595 ms
# [2024-03-25 20:50:02.598] [info] Simulating optical element 4/4
# [2024-03-25 20:50:03.682] [info] Elapsed time for optical element: 1083.6456 ms
# [2024-03-25 20:50:03.683] [info] Running phase step 2/5
# [2024-03-25 20:50:03.685] [info] Simulating optical element 4/4
# [2024-03-25 20:50:04.772] [info] Elapsed time for optical element: 1087.7568 ms
# [2024-03-25 20:50:04.774] [info] Running phase step 3/5
# [2024-03-25 20:50:04.776] [info] Simulating optical element 4/4
# [2024-03-25 20:50:05.859] [info] Elapsed time for optical element: 1083.7052 ms
# [2024-03-25 20:50:05.861] [info] Running phase step 4/5
# [2024-03-25 20:50:05.862] [info] Simulating optical element 4/4
# [2024-03-25 20:50:06.948] [info] Elapsed time for optical element: 1085.2836 ms
# [2024-03-25 20:50:06.949] [info] Running phase step 5/5
# [2024-03-25 20:50:06.949] [info] Simulating optical element 4/4
# [2024-03-25 20:50:08.033] [info] Elapsed time for optical element: 1083.836 ms
# [2024-03-25 20:50:08.035] [info] Simulation finished in 12.010285565 seconds
# [2024-03-25 20:50:08.330] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000029
# [2024-03-25 20:50:08.755] [info] Simulating optical element 1/4
# [2024-03-25 20:50:14.619] [info] Elapsed time for optical element: 5863.511 ms
# [2024-03-25 20:50:14.619] [info] Simulating optical element 2/4
# [2024-03-25 20:50:14.643] [info] Elapsed time for optical element: 23.778528 ms
# [2024-03-25 20:50:14.664] [info] Simulating optical element 3/4
# [2024-03-25 20:50:14.965] [info] Elapsed time for optical element: 300.3005 ms
# [2024-03-25 20:50:14.991] [info] Simulating optical element 4/4
# [2024-03-25 20:50:16.122] [info] Elapsed time for optical element: 1131.6962 ms
# [2024-03-25 20:50:16.124] [info] Running phase step 2/5
# [2024-03-25 20:50:16.126] [info] Simulating optical element 4/4
# [2024-03-25 20:50:17.259] [info] Elapsed time for optical element: 1132.9618 ms
# [2024-03-25 20:50:17.260] [info] Running phase step 3/5
# [2024-03-25 20:50:17.262] [info] Simulating optical element 4/4
# [2024-03-25 20:50:18.395] [info] Elapsed time for optical element: 1133.0498 ms
# [2024-03-25 20:50:18.396] [info] Running phase step 4/5
# [2024-03-25 20:50:18.398] [info] Simulating optical element 4/4
# [2024-03-25 20:50:19.533] [info] Elapsed time for optical element: 1135.607 ms
# [2024-03-25 20:50:19.535] [info] Running phase step 5/5
# [2024-03-25 20:50:19.535] [info] Simulating optical element 4/4
# [2024-03-25 20:50:20.662] [info] Elapsed time for optical element: 1127.4474 ms
# [2024-03-25 20:50:20.664] [info] Simulation finished in 12.333477644 seconds
# [2024-03-25 20:50:20.949] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000030
# [2024-03-25 20:50:21.372] [info] Simulating optical element 1/4
# [2024-03-25 20:50:27.182] [info] Elapsed time for optical element: 5809.0537 ms
# [2024-03-25 20:50:27.182] [info] Simulating optical element 2/4
# [2024-03-25 20:50:27.205] [info] Elapsed time for optical element: 23.534304 ms
# [2024-03-25 20:50:27.227] [info] Simulating optical element 3/4
# [2024-03-25 20:50:27.515] [info] Elapsed time for optical element: 287.93057 ms
# [2024-03-25 20:50:27.539] [info] Simulating optical element 4/4
# [2024-03-25 20:50:28.624] [info] Elapsed time for optical element: 1084.4816 ms
# [2024-03-25 20:50:28.625] [info] Running phase step 2/5
# [2024-03-25 20:50:28.627] [info] Simulating optical element 4/4
# ...
# [2024-03-25 21:16:25.992] [info] Simulating optical element 4/4
# [2024-03-25 21:16:27.102] [info] Elapsed time for optical element: 1109.9249 ms
# [2024-03-25 21:16:27.103] [info] Running phase step 4/5
# [2024-03-25 21:16:27.105] [info] Simulating optical element 4/4
# [2024-03-25 21:16:28.214] [info] Elapsed time for optical element: 1109.2357 ms
# [2024-03-25 21:16:28.216] [info] Running phase step 5/5
# [2024-03-25 21:16:28.216] [info] Simulating optical element 4/4
# [2024-03-25 21:16:29.319] [info] Elapsed time for optical element: 1103.6646 ms
# [2024-03-25 21:16:29.321] [info] Simulation finished in 12.128114428 seconds
# [2024-03-25 21:16:29.566] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000155
# [2024-03-25 21:16:29.870] [info] Simulating optical element 1/4
# [2024-03-25 21:16:35.771] [info] Elapsed time for optical element: 5901.163 ms
# [2024-03-25 21:16:35.771] [info] Simulating optical element 2/4
# [2024-03-25 21:16:35.795] [info] Elapsed time for optical element: 24.171553 ms
# [2024-03-25 21:16:35.818] [info] Simulating optical element 3/4
# [2024-03-25 21:16:36.121] [info] Elapsed time for optical element: 303.75818 ms
# [2024-03-25 21:16:36.147] [info] Simulating optical element 4/4
# [2024-03-25 21:16:37.285] [info] Elapsed time for optical element: 1137.5994 ms
# [2024-03-25 21:16:37.286] [info] Running phase step 2/5
# [2024-03-25 21:16:37.288] [info] Simulating optical element 4/4
# [2024-03-25 21:16:38.425] [info] Elapsed time for optical element: 1137.4241 ms
# [2024-03-25 21:16:38.426] [info] Running phase step 3/5
# [2024-03-25 21:16:38.428] [info] Simulating optical element 4/4
# [2024-03-25 21:16:39.567] [info] Elapsed time for optical element: 1138.6008 ms
# [2024-03-25 21:16:39.568] [info] Running phase step 4/5
# [2024-03-25 21:16:39.570] [info] Simulating optical element 4/4
# [2024-03-25 21:16:40.709] [info] Elapsed time for optical element: 1138.4895 ms
# [2024-03-25 21:16:40.710] [info] Running phase step 5/5
# [2024-03-25 21:16:40.710] [info] Simulating optical element 4/4
# [2024-03-25 21:16:41.845] [info] Elapsed time for optical element: 1135.5128 ms
# [2024-03-25 21:16:41.847] [info] Simulation finished in 12.280364987 seconds
# [2024-03-25 21:16:42.086] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000156
# [2024-03-25 21:16:42.426] [info] Simulating optical element 1/4
# [2024-03-25 21:16:48.283] [info] Elapsed time for optical element: 5856.8027 ms
# [2024-03-25 21:16:48.283] [info] Simulating optical element 2/4
# [2024-03-25 21:16:48.306] [info] Elapsed time for optical element: 23.361568 ms
# [2024-03-25 21:16:48.327] [info] Simulating optical element 3/4
# [2024-03-25 21:16:48.610] [info] Elapsed time for optical element: 282.60342 ms
# [2024-03-25 21:16:48.634] [info] Simulating optical element 4/4
# [2024-03-25 21:16:49.733] [info] Elapsed time for optical element: 1098.7904 ms
# [2024-03-25 21:16:49.734] [info] Running phase step 2/5
# [2024-03-25 21:16:49.736] [info] Simulating optical element 4/4
# [2024-03-25 21:16:50.840] [info] Elapsed time for optical element: 1104.236 ms
# [2024-03-25 21:16:50.841] [info] Running phase step 3/5
# [2024-03-25 21:16:50.843] [info] Simulating optical element 4/4
# [2024-03-25 21:16:51.948] [info] Elapsed time for optical element: 1104.6094 ms
# [2024-03-25 21:16:51.949] [info] Running phase step 4/5
# [2024-03-25 21:16:51.951] [info] Simulating optical element 4/4
# [2024-03-25 21:16:53.055] [info] Elapsed time for optical element: 1104.0449 ms
# [2024-03-25 21:16:53.056] [info] Running phase step 5/5
# [2024-03-25 21:16:53.056] [info] Simulating optical element 4/4
# [2024-03-25 21:16:54.156] [info] Elapsed time for optical element: 1099.5831 ms
# [2024-03-25 21:16:54.158] [info] Simulation finished in 12.070790835 seconds
# [2024-03-25 21:16:54.404] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000157
# [2024-03-25 21:16:54.743] [info] Simulating optical element 1/4
# [2024-03-25 21:17:00.623] [info] Elapsed time for optical element: 5879.982 ms
# [2024-03-25 21:17:00.623] [info] Simulating optical element 2/4
# [2024-03-25 21:17:00.647] [info] Elapsed time for optical element: 23.935936 ms
# [2024-03-25 21:17:00.669] [info] Simulating optical element 3/4
# [2024-03-25 21:17:00.968] [info] Elapsed time for optical element: 298.54712 ms
# [2024-03-25 21:17:00.993] [info] Simulating optical element 4/4
# [2024-03-25 21:17:02.118] [info] Elapsed time for optical element: 1124.99 ms
# [2024-03-25 21:17:02.119] [info] Running phase step 2/5
# [2024-03-25 21:17:02.121] [info] Simulating optical element 4/4
# [2024-03-25 21:17:03.246] [info] Elapsed time for optical element: 1125.372 ms
# [2024-03-25 21:17:03.248] [info] Running phase step 3/5
# [2024-03-25 21:17:03.250] [info] Simulating optical element 4/4
# [2024-03-25 21:17:04.376] [info] Elapsed time for optical element: 1126.699 ms
# [2024-03-25 21:17:04.378] [info] Running phase step 4/5
# [2024-03-25 21:17:04.379] [info] Simulating optical element 4/4
# [2024-03-25 21:17:05.502] [info] Elapsed time for optical element: 1123.0192 ms
# [2024-03-25 21:17:05.504] [info] Running phase step 5/5
# [2024-03-25 21:17:05.504] [info] Simulating optical element 4/4
# [2024-03-25 21:17:06.628] [info] Elapsed time for optical element: 1124.6122 ms
# [2024-03-25 21:17:06.630] [info] Simulation finished in 12.225821523 seconds
# [2024-03-25 21:17:06.875] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000158
# [2024-03-25 21:17:07.212] [info] Simulating optical element 1/4
# [2024-03-25 21:17:13.122] [info] Elapsed time for optical element: 5909.881 ms
# [2024-03-25 21:17:13.122] [info] Simulating optical element 2/4
# [2024-03-25 21:17:13.146] [info] Elapsed time for optical element: 24.095648 ms
# [2024-03-25 21:17:13.168] [info] Simulating optical element 3/4
# [2024-03-25 21:17:13.471] [info] Elapsed time for optical element: 302.94653 ms
# [2024-03-25 21:17:13.497] [info] Simulating optical element 4/4
# [2024-03-25 21:17:14.661] [info] Elapsed time for optical element: 1164.6072 ms
# [2024-03-25 21:17:14.663] [info] Running phase step 2/5
# [2024-03-25 21:17:14.665] [info] Simulating optical element 4/4
# [2024-03-25 21:17:15.825] [info] Elapsed time for optical element: 1160.6874 ms
# [2024-03-25 21:17:15.827] [info] Running phase step 3/5
# [2024-03-25 21:17:15.828] [info] Simulating optical element 4/4
# [2024-03-25 21:17:16.989] [info] Elapsed time for optical element: 1160.1367 ms
# [2024-03-25 21:17:16.990] [info] Running phase step 4/5
# [2024-03-25 21:17:16.992] [info] Simulating optical element 4/4
# [2024-03-25 21:17:18.152] [info] Elapsed time for optical element: 1160.5612 ms
# [2024-03-25 21:17:18.153] [info] Running phase step 5/5
# [2024-03-25 21:17:18.153] [info] Simulating optical element 4/4
# [2024-03-25 21:17:19.315] [info] Elapsed time for optical element: 1161.7803 ms
# [2024-03-25 21:17:19.317] [info] Simulation finished in 12.441821906 seconds
# [2024-03-25 21:17:19.564] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000159
# [2024-03-25 21:17:19.900] [info] Simulating optical element 1/4
# [2024-03-25 21:17:25.796] [info] Elapsed time for optical element: 5896.227 ms
# [2024-03-25 21:17:25.796] [info] Simulating optical element 2/4
# [2024-03-25 21:17:25.820] [info] Elapsed time for optical element: 24.271872 ms
# [2024-03-25 21:17:25.842] [info] Simulating optical element 3/4
# [2024-03-25 21:17:26.148] [info] Elapsed time for optical element: 305.17236 ms
# [2024-03-25 21:17:26.173] [info] Simulating optical element 4/4
# [2024-03-25 21:17:27.319] [info] Elapsed time for optical element: 1145.7429 ms
# [2024-03-25 21:17:27.320] [info] Running phase step 2/5
# [2024-03-25 21:17:27.322] [info] Simulating optical element 4/4
# [2024-03-25 21:17:28.468] [info] Elapsed time for optical element: 1146.1139 ms
# [2024-03-25 21:17:28.469] [info] Running phase step 3/5
# [2024-03-25 21:17:28.471] [info] Simulating optical element 4/4
# [2024-03-25 21:17:29.619] [info] Elapsed time for optical element: 1147.3834 ms
# [2024-03-25 21:17:29.620] [info] Running phase step 4/5
# [2024-03-25 21:17:29.622] [info] Simulating optical element 4/4
# [2024-03-25 21:17:30.768] [info] Elapsed time for optical element: 1146.5073 ms
# [2024-03-25 21:17:30.770] [info] Running phase step 5/5
# [2024-03-25 21:17:30.770] [info] Simulating optical element 4/4
# [2024-03-25 21:17:31.911] [info] Elapsed time for optical element: 1141.2957 ms
# [2024-03-25 21:17:31.913] [info] Simulation finished in 12.348475499 seconds
# [2024-03-25 21:17:32.127] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000160
# [2024-03-25 21:17:32.463] [info] Simulating optical element 1/4
# [2024-03-25 21:17:38.331] [info] Elapsed time for optical element: 5867.87 ms
# [2024-03-25 21:17:38.331] [info] Simulating optical element 2/4
# [2024-03-25 21:17:38.355] [info] Elapsed time for optical element: 23.490591 ms
# [2024-03-25 21:17:38.376] [info] Simulating optical element 3/4
# [2024-03-25 21:17:38.669] [info] Elapsed time for optical element: 292.81912 ms
# [2024-03-25 21:17:38.694] [info] Simulating optical element 4/4
# [2024-03-25 21:17:39.803] [info] Elapsed time for optical element: 1108.9873 ms
# [2024-03-25 21:17:39.804] [info] Running phase step 2/5
# [2024-03-25 21:17:39.806] [info] Simulating optical element 4/4
# [2024-03-25 21:17:40.914] [info] Elapsed time for optical element: 1107.7384 ms
# [2024-03-25 21:17:40.915] [info] Running phase step 3/5
# [2024-03-25 21:17:40.917] [info] Simulating optical element 4/4
# [2024-03-25 21:17:42.025] [info] Elapsed time for optical element: 1107.3198 ms
# [2024-03-25 21:17:42.026] [info] Running phase step 4/5
# [2024-03-25 21:17:42.028] [info] Simulating optical element 4/4
# [2024-03-25 21:17:43.136] [info] Elapsed time for optical element: 1108.441 ms
# [2024-03-25 21:17:43.137] [info] Running phase step 5/5
# [2024-03-25 21:17:43.137] [info] Simulating optical element 4/4
# [2024-03-25 21:17:44.242] [info] Elapsed time for optical element: 1104.762 ms
# [2024-03-25 21:17:44.244] [info] Simulation finished in 12.116523633 seconds
# [2024-03-25 21:17:44.491] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000161
# [2024-03-25 21:17:44.819] [info] Simulating optical element 1/4
# [2024-03-25 21:17:50.693] [info] Elapsed time for optical element: 5873.6455 ms
# [2024-03-25 21:17:50.693] [info] Simulating optical element 2/4
# [2024-03-25 21:17:50.717] [info] Elapsed time for optical element: 23.46112 ms
# [2024-03-25 21:17:50.738] [info] Simulating optical element 3/4
# [2024-03-25 21:17:51.032] [info] Elapsed time for optical element: 293.9683 ms
# [2024-03-25 21:17:51.057] [info] Simulating optical element 4/4
# [2024-03-25 21:17:52.178] [info] Elapsed time for optical element: 1121.0925 ms
# [2024-03-25 21:17:52.180] [info] Running phase step 2/5
# [2024-03-25 21:17:52.181] [info] Simulating optical element 4/4
# [2024-03-25 21:17:53.303] [info] Elapsed time for optical element: 1121.4319 ms
# [2024-03-25 21:17:53.304] [info] Running phase step 3/5
# [2024-03-25 21:17:53.306] [info] Simulating optical element 4/4
# [2024-03-25 21:17:54.426] [info] Elapsed time for optical element: 1120.1595 ms
# [2024-03-25 21:17:54.427] [info] Running phase step 4/5
# [2024-03-25 21:17:54.429] [info] Simulating optical element 4/4
# [2024-03-25 21:17:55.550] [info] Elapsed time for optical element: 1120.6615 ms
# [2024-03-25 21:17:55.551] [info] Running phase step 5/5
# [2024-03-25 21:17:55.551] [info] Simulating optical element 4/4
# [2024-03-25 21:17:56.668] [info] Elapsed time for optical element: 1116.4764 ms
# [2024-03-25 21:17:56.670] [info] Simulation finished in 12.177321943 seconds
# [2024-03-25 21:17:56.898] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000162
# [2024-03-25 21:17:57.231] [info] Simulating optical element 1/4
# [2024-03-25 21:18:03.096] [info] Elapsed time for optical element: 5865.46 ms
# [2024-03-25 21:18:03.096] [info] Simulating optical element 2/4
# [2024-03-25 21:18:03.121] [info] Elapsed time for optical element: 24.11376 ms
# [2024-03-25 21:18:03.142] [info] Simulating optical element 3/4
# [2024-03-25 21:18:03.444] [info] Elapsed time for optical element: 301.50845 ms
# [2024-03-25 21:18:03.469] [info] Simulating optical element 4/4
# [2024-03-25 21:18:04.598] [info] Elapsed time for optical element: 1128.5581 ms
# [2024-03-25 21:18:04.599] [info] Running phase step 2/5
# [2024-03-25 21:18:04.601] [info] Simulating optical element 4/4
# [2024-03-25 21:18:05.726] [info] Elapsed time for optical element: 1125.0405 ms
# [2024-03-25 21:18:05.727] [info] Running phase step 3/5
# [2024-03-25 21:18:05.729] [info] Simulating optical element 4/4
# [2024-03-25 21:18:06.857] [info] Elapsed time for optical element: 1127.6655 ms
# [2024-03-25 21:18:06.858] [info] Running phase step 4/5
# [2024-03-25 21:18:06.860] [info] Simulating optical element 4/4
# [2024-03-25 21:18:07.988] [info] Elapsed time for optical element: 1127.9247 ms
# [2024-03-25 21:18:07.989] [info] Running phase step 5/5
# [2024-03-25 21:18:07.989] [info] Simulating optical element 4/4
# [2024-03-25 21:18:09.113] [info] Elapsed time for optical element: 1123.7124 ms
# [2024-03-25 21:18:09.115] [info] Simulation finished in 12.216462606 seconds
# [2024-03-25 21:18:09.362] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000163
# [2024-03-25 21:18:09.699] [info] Simulating optical element 1/4
# [2024-03-25 21:18:15.603] [info] Elapsed time for optical element: 5904.599 ms
# [2024-03-25 21:18:15.603] [info] Simulating optical element 2/4
# [2024-03-25 21:18:15.627] [info] Elapsed time for optical element: 24.016895 ms
# [2024-03-25 21:18:15.650] [info] Simulating optical element 3/4
# [2024-03-25 21:18:15.960] [info] Elapsed time for optical element: 310.36557 ms
# [2024-03-25 21:18:15.985] [info] Simulating optical element 4/4
# [2024-03-25 21:18:17.128] [info] Elapsed time for optical element: 1142.3038 ms
# [2024-03-25 21:18:17.129] [info] Running phase step 2/5
# [2024-03-25 21:18:17.131] [info] Simulating optical element 4/4
# [2024-03-25 21:18:18.277] [info] Elapsed time for optical element: 1146.4702 ms
# [2024-03-25 21:18:18.278] [info] Running phase step 3/5
# [2024-03-25 21:18:18.280] [info] Simulating optical element 4/4
# [2024-03-25 21:18:19.426] [info] Elapsed time for optical element: 1145.3628 ms
# [2024-03-25 21:18:19.427] [info] Running phase step 4/5
# [2024-03-25 21:18:19.429] [info] Simulating optical element 4/4
# [2024-03-25 21:18:20.576] [info] Elapsed time for optical element: 1146.9851 ms
# [2024-03-25 21:18:20.577] [info] Running phase step 5/5
# [2024-03-25 21:18:20.577] [info] Simulating optical element 4/4
# [2024-03-25 21:18:21.721] [info] Elapsed time for optical element: 1143.7156 ms
# [2024-03-25 21:18:21.723] [info] Simulation finished in 12.36007054 seconds
# [2024-03-25 21:18:21.965] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204358207140/00000164
# [2024-03-25 21:18:22.298] [info] Simulating optical element 1/4
# [2024-03-25 21:18:28.160] [info] Elapsed time for optical element: 5861.9824 ms
# [2024-03-25 21:18:28.160] [info] Simulating optical element 2/4
# [2024-03-25 21:18:28.183] [info] Elapsed time for optical element: 23.387936 ms
# [2024-03-25 21:18:28.205] [info] Simulating optical element 3/4
# [2024-03-25 21:18:28.493] [info] Elapsed time for optical element: 288.5808 ms
# [2024-03-25 21:18:28.518] [info] Simulating optical element 4/4
# [2024-03-25 21:18:29.621] [info] Elapsed time for optical element: 1103.0897 ms
# [2024-03-25 21:18:29.623] [info] Running phase step 2/5
# [2024-03-25 21:18:29.624] [info] Simulating optical element 4/4
# [2024-03-25 21:18:30.726] [info] Elapsed time for optical element: 1101.8447 ms
# [2024-03-25 21:18:30.727] [info] Running phase step 3/5
# [2024-03-25 21:18:30.729] [info] Simulating optical element 4/4
# [2024-03-25 21:18:31.831] [info] Elapsed time for optical element: 1101.8855 ms
# [2024-03-25 21:18:31.833] [info] Running phase step 4/5
# [2024-03-25 21:18:31.834] [info] Simulating optical element 4/4

# %%
h0 = 180e-6

# %%
config_dict = {
        "sim_params": {
            "N": N,
            "dx": dx,
            "z_detector": z_g2 + 370e-6,
            "detector_size": 0.004,
            "detector_pixel_size_x": 1e-7,
            "detector_pixel_size_y": 1.0,
            "chunk_size": 256 * 1024 * 1024 // 16,  # use 256MB chunks
        },
        "use_disk_vector": False,
        "save_final_u_vectors": False,
        "dtype": "c8",
        "multisource": {
            "type": "points",
            "energy_range": [11000, 70000],
            "x_range": [-10e-6, 10e-6],
            "z": 0.0,
            "nr_source_points": 1000,
            "seed": 1,
            "spectrum": path_to_spectrum,
        },
        "elements": [
            {
                "type": "grating",
                "pitch": p0,
                "dc": [0.5, 0.5],
                "z_start": z_g0,
                "thickness": h0,
                "nr_steps": 30,
                "x_positions": [0.0],
                "substrate_thickness": 500*1e-6 - h0,
                "mat_a": ["C5H8O2", 1.19],
                "mat_b": ["Au", 19.32],
                "mat_substrate": ["C", 2.26],
            },
            {
                "type": "grating",
                "pitch": p1,
                "dc": [0.5, 0.5],
                "z_start": z_g1,
                "thickness": h1,
                "nr_steps": 10,
                "x_positions": [0.0],
                "substrate_thickness": 200 * 1e-6 - h1,
                "mat_a": ["Si", 2.34],
                "mat_b": None,
                "mat_substrate": ["Si", 2.34],
            },
            {
                "type": "sample",
                "z_start": z_g2,
                "pixel_size_x": dx_g2,
                "pixel_size_z": dz_g2,
                "grid_path": grid_path_g2,
                "materials": [["Au", 19.32], ["Si", 2.34]],
                "x_positions": (np.arange(5) * p2/5).tolist(),
            },
            {
                "type": "grating",
                "pitch": p2,
                "dc": [1.0, 1.0],
                "z_start": z_g2 + 147e-6,
                "thickness": 1e-10,
                "nr_steps": 0,
                "x_positions": (np.arange(5) * p2/5).tolist(),
                "substrate_thickness": 370*1e-6 - 147e-6,
                "mat_a": ["Si", 2.34],
                "mat_b": ["Si", 2.34],
                "mat_substrate": ["Si", 2.34],
            },
        ],
}

sim_path = multisim.setup_simulation(config_dict, Path("."), simulations_dir)

# %%
for i in range(1000):
    os.system(f"CUDA_VISIBLE_DEVICES=0 ../rave-sim/fast-wave/build-Release/fastwave -s {i} {sim_path}")
