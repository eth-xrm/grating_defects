# %%
# Copyright (c) 2025, ETH Zurich

# %%
import sys
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import os
import scipy.stats as stats
import scipy.ndimage
from tqdm import tqdm
import spekpy as spk
import h5py

from scipy import interpolate

# %%
rave_sim_dir = Path('../rave-sim').resolve()
simulations_dir = Path('<PATH_TO_STORE_SIMULATIONS>')
scratch_dir = simulations_dir


sys.path.insert(0, str(rave_sim_dir / "nist_lookup"))
from nist_lookup.xraydb_plugin import xray_delta_beta

# %%
sys.path.insert(0, str(rave_sim_dir / "big-wave"))
import multisim
import config
import util
import propagation

# %%
def calculate_G1_height(eng):
    # constants
    h = 6.62607004 * 10**(-34) # planck constant in mˆ2 kg / s
    c_0 = 299792458 # speed of light in m / s
    eV_to_joule = 1.602176634*10**(-19)
    N_A = 6.02214086 * 10**23 #[1/mol]
    
    lambda_ = h * c_0 / (eng*eV_to_joule)
    delta_diff = xray_delta_beta('Si', 2.34, eng)[0]
    height = np.pi  * lambda_ / (2*np.pi * delta_diff)

    return height


def signal_retrieval_least_squares(data, period=None, axis=-1):
    if axis != -1:
        data = np.moveaxis(data, axis, -1)

    nsteps = data.shape[-1]

    if period is None:
        period = nsteps

    phi = np.linspace(0, 2 * np.pi * nsteps / (period), nsteps, endpoint=False)
    M = np.c_[np.sin(phi), np.cos(phi), np.ones(nsteps)]
    res, chi2, _rank, _sing_vals = np.linalg.lstsq(M, data.reshape((-1, nsteps)).T, rcond=-1)

    res = res.T.reshape((*data.shape[:-1], -1))

    dabs = res[...,2]
    dphase = -np.arctan2(res[...,0], res[...,1])
    dvis = np.sqrt(res[...,0]**2 + res[...,1]**2) / dabs

    # normalization to the total number of counts
    dabs *= nsteps

    return dabs, dphase, dvis, np.nanmean(chi2)


def calculate_pixel_intensity(x, fringe, pxEdges, statistics = 'sum'):
    fringeStats = stats.binned_statistic(x, fringe, bins=pxEdges, statistic = statistics)
    return fringeStats.statistic

def perform_binned_signal_retrieval(x, wf, pxSize, nrSteps, plot_curve = True):
    leftSide = np.arange(0-pxSize/2, np.min(x), -pxSize)
    rightSide = np.arange(0 + pxSize/2, np.max(x), pxSize)
    pxEdges = np.concatenate([np.flip(leftSide), rightSide])
    int_px = []
    for i in range(nrSteps):
        int_px.append(calculate_pixel_intensity(x, wf[i,:], pxEdges))
    int_px = np.asarray(int_px)

    trans, phase, vis, _ = signal_retrieval_least_squares(int_px, period = nrSteps, axis = 0)
    if plot_curve:
        plot_curves(trans, phase, vis, pxEdges)
    return int_px, trans, phase, vis, pxEdges

def plot_curves(trans, phase, vis, pxEdges):

    fig, axs = plt.subplots(figsize=(15,6), sharex = True, nrows = 1, ncols = 2)
    axs[0].plot(pxEdges[1:], trans, label = 'Transmission')
    axs[0].set_title('Transmission')
    axs[1].plot(pxEdges[1:], vis, label = 'Visibility')
    axs[1].set_title('Visibility')

def perform_binning(x, wf, pxSize):
    leftSide = np.arange(0-pxSize/2, np.min(x), -pxSize)
    rightSide = np.arange(0 + pxSize/2, np.max(x), pxSize)
    pxEdges = np.concatenate([np.flip(leftSide), rightSide])
    int_px = calculate_pixel_intensity(x, wf, pxEdges, statistics = 'mean')
    return int_px


    #np.random.seed(1)
    
    sample_energy = np.random.choice(x, p=y)
    if sample_energy >= low_threshold:
        return True
    else:
        return False
    
    
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

def calculate_SNR(wavefronts, detector_x, phase_steps):
    summed_wf = np.zeros_like(wavefronts[0][0])
        
    for point in wavefronts:
        wf, x_point, eng = point
        
        summed_wf += wf

    return summed_wf

def get_subdict(dict_, idx):
    sub_dict = {}
    for key in dict_.keys():
        sub_dict[key] = dict_[key][idx]
    return sub_dict

def calc_Vis_theoretical(eng, Edes,m):
    V = 2/np.pi * np.abs(np.sin(np.pi / 2 * Edes / eng)**2 * np.sin(m * np.pi / 2 * Edes / eng))
    return V

def mu_h2o(eng):
    lambda_ = h * c_0 / (eng*eV_to_joule)
    beta = xray_delta_beta('H2O', 1.0, eng)[1]
    return 4 * np.pi / lambda_ * beta

# %%
# constants
h = 6.62607004 * 10**(-34) # planck constant in mˆ2 kg / s
c_0 = 299792458 # speed of light in m / s
eV_to_joule = 1.602176634*10**(-19)
N_A = 6.02214086 * 10**23 #[1/mol]
E_des = 46000

lambda_ = h * c_0 / (E_des*eV_to_joule)
p2 = 4.2*10**(-6)
p0 = p1 = p2

Dn_3 = 3*p2**2/(2*lambda_) / 2
print(Dn_3)

z_g0 = 0.218
z_g1 = z_g0 + Dn_3
z_g2 = z_g0 + 2*Dn_3
z_detector = z_g2 + 0.01

h2 = 180e-6
h1 = 59e-6 

dc0 = [0.5, 0.5]
dc2 = [0.24, 0.52]

print("Z0: ", z_g0)
print("Z1: ", z_g1)
print("Z2: ", z_g2)
print("Z Detector: ", z_detector)

print(Dn_3)
# Out:
# 0.49085288108789216
# Z0:  0.218
# Z1:  0.7088528810878921
# Z2:  1.1997057621757843
# Z Detector:  1.2097057621757843
# 0.49085288108789216

# %%
2200/ 4200
# Out:
# 0.5238095238095238

# %%
N = 2**26
max_energy = 70000
dx = propagation.max_dx(z_g0, 10e-6, N, propagation.convert_energy_wavelength(max_energy))

# %% [markdown]
# # Now with both gratings modelled

# %%
meta_data_g0 = np.load('../grating_models/DRIE_models/mask_g0_different_dc_2.npz')
meta_data_g2 = np.load('../grating_models/DRIE_models/mask_g2_different_dc_2.npz')



grid_path_g0 = os.path.abspath('../grating_models/DRIE_models/mask_g0_different_dc_2.npy')
grid_path_g2 = os.path.abspath('../grating_models/DRIE_models/mask_g2_different_dc_2.npy')


dx_g0 = meta_data_g0['x'][1].item()-meta_data_g0['x'][0].item()
dz_g0 = meta_data_g0['z'].item()

dx_g2 = meta_data_g2['x'][1].item()-meta_data_g2['x'][0].item()
dz_g2 = meta_data_g2['z'].item()

# %%
s = spk.Spek(kvp=70, dk = 0.1, th = 10) # Create a spectrum

s.filter('Be', 0.15) # Create a spectrum
k, f = s.get_spectrum(edges=True) # Get the spectrum

energyRange = [4000, 70000]
dE = 100
filtering = 0.000

energies = np.arange(5, 70+0.1, 0.1)*1e3


tube_spectrum_txt = interpolate.interp1d(k*1e3, f, fill_value = 'extrapolate')
spec_txt = tube_spectrum_txt(energies)

with h5py.File('../spectra/spectrum_70_spekpy_unfiltered.h5', 'w') as h5:
    h5.create_dataset('pdf', data =  spec_txt/ np.sum(spec_txt))
    h5.create_dataset('energy', data = energies) 

path_to_spectrum = os.path.abspath('../spectra/spectrum_70_spekpy_unfiltered.h5')

# %%
config_dict = {
        "sim_params": {
            "N": N,
            "dx": dx,
            "z_detector": z_g2 + 500e-6,
            "detector_size": 0.004,
            "detector_pixel_size_x": 1e-7,
            "detector_pixel_size_y": 1.0,
            "chunk_size": 256 * 1024 * 1024 // 16,  # use 256MB chunks
        },
        "use_disk_vector": False,
        "save_final_u_vectors": False,
        "dtype": "c8",
        "multisource": {
            "type": "points",
            "energy_range": [11000, 70000],
            "x_range": [-10e-6, 10e-6],
            "z": 0.0,
            "nr_source_points": 1000,
            "seed": 1,
            "spectrum": path_to_spectrum,
        },
        "elements": [
            {
                "type": "sample",
                "z_start": z_g0,
                "pixel_size_x": dx_g0,
                "pixel_size_z": dz_g0,
                "grid_path": grid_path_g0,
                "materials": [["Au", 19.32], ["Si", 2.34]],
                "x_positions": [0.0],
            },
            {
                "type": "grating",
                "pitch": p0,
                "dc": [1.0, 1.0],
                "z_start": z_g0 + 117e-6,
                "thickness": 1e-8,
                "nr_steps": 0,
                "x_positions": [0.0],
                "substrate_thickness": 370*1e-6 - 117e-6 - 1e-8,
                "mat_a": ["Si", 2.34],
                "mat_b": ["Si", 2.34],
                "mat_substrate": ["Si", 2.34],
            },
            {
                "type": "grating",
                "pitch": p1,
                "dc": [0.5, 0.5],
                "z_start": z_g1,
                "thickness": h1,
                "nr_steps": 10,
                "x_positions": [0.0],
                "substrate_thickness": 200 * 1e-6 - h1,
                "mat_a": ["Si", 2.34],
                "mat_b": None,
                "mat_substrate": ["Si", 2.34],
            },
            {
                "type": "grating",
                "pitch": p2,
                "dc": [0.5, 0.5],
                "z_start": z_g2,
                "thickness": h2,
                "nr_steps": 40,
                "x_positions": (np.arange(5) * p2/5).tolist(),
                "substrate_thickness": 500*1e-6 - h2,
                "mat_a": ["C5H8O2", 1.19],
                "mat_b": ["Au", 19.32],
                "mat_substrate": ["C", 2.26],
            },
        ],
}

sim_path = multisim.setup_simulation(config_dict, Path("."), simulations_dir)
# Out:
# 2024-03-25 20:44:25,091 INFO: Setting up simulation
# 2024-03-25 20:45:23,860 INFO: Finished setting up simulation in /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776

# %%
for i in range(1000):
    os.system(f"CUDA_VISIBLE_DEVICES=1 ../rave-sim/fast-wave/build-Release/fastwave -s {i} {sim_path}")
# Out:
# [2024-03-25 20:45:24.249] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000000
# [2024-03-25 20:45:24.684] [info] Simulating optical element 1/4
# [2024-03-25 20:45:30.072] [info] Elapsed time for optical element: 5388.276 ms
# [2024-03-25 20:45:30.072] [info] Simulating optical element 2/4
# [2024-03-25 20:45:30.095] [info] Elapsed time for optical element: 22.8864 ms
# [2024-03-25 20:45:30.116] [info] Simulating optical element 3/4
# [2024-03-25 20:45:30.389] [info] Elapsed time for optical element: 273.0407 ms
# [2024-03-25 20:45:30.413] [info] Simulating optical element 4/4
# [2024-03-25 20:45:31.435] [info] Elapsed time for optical element: 1022.72797 ms
# [2024-03-25 20:45:31.437] [info] Running phase step 2/5
# [2024-03-25 20:45:31.439] [info] Simulating optical element 4/4
# [2024-03-25 20:45:32.463] [info] Elapsed time for optical element: 1024.6134 ms
# [2024-03-25 20:45:32.464] [info] Running phase step 3/5
# [2024-03-25 20:45:32.466] [info] Simulating optical element 4/4
# [2024-03-25 20:45:33.493] [info] Elapsed time for optical element: 1026.5167 ms
# [2024-03-25 20:45:33.494] [info] Running phase step 4/5
# [2024-03-25 20:45:33.496] [info] Simulating optical element 4/4
# [2024-03-25 20:45:34.524] [info] Elapsed time for optical element: 1028.0408 ms
# [2024-03-25 20:45:34.525] [info] Running phase step 5/5
# [2024-03-25 20:45:34.525] [info] Simulating optical element 4/4
# [2024-03-25 20:45:35.540] [info] Elapsed time for optical element: 1015.26733 ms
# [2024-03-25 20:45:35.542] [info] Simulation finished in 11.292623141 seconds
# [2024-03-25 20:45:36.005] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000001
# [2024-03-25 20:45:36.447] [info] Simulating optical element 1/4
# [2024-03-25 20:45:41.949] [info] Elapsed time for optical element: 5502.2964 ms
# [2024-03-25 20:45:41.949] [info] Simulating optical element 2/4
# [2024-03-25 20:45:41.972] [info] Elapsed time for optical element: 23.189505 ms
# [2024-03-25 20:45:41.994] [info] Simulating optical element 3/4
# [2024-03-25 20:45:42.276] [info] Elapsed time for optical element: 282.6199 ms
# [2024-03-25 20:45:42.300] [info] Simulating optical element 4/4
# [2024-03-25 20:45:43.362] [info] Elapsed time for optical element: 1061.5773 ms
# [2024-03-25 20:45:43.363] [info] Running phase step 2/5
# [2024-03-25 20:45:43.365] [info] Simulating optical element 4/4
# [2024-03-25 20:45:44.433] [info] Elapsed time for optical element: 1067.5372 ms
# [2024-03-25 20:45:44.434] [info] Running phase step 3/5
# [2024-03-25 20:45:44.436] [info] Simulating optical element 4/4
# [2024-03-25 20:45:45.514] [info] Elapsed time for optical element: 1078.0007 ms
# [2024-03-25 20:45:45.515] [info] Running phase step 4/5
# [2024-03-25 20:45:45.517] [info] Simulating optical element 4/4
# [2024-03-25 20:45:46.593] [info] Elapsed time for optical element: 1076.0903 ms
# [2024-03-25 20:45:46.594] [info] Running phase step 5/5
# [2024-03-25 20:45:46.594] [info] Simulating optical element 4/4
# [2024-03-25 20:45:47.659] [info] Elapsed time for optical element: 1064.4675 ms
# [2024-03-25 20:45:47.660] [info] Simulation finished in 11.653752984 seconds
# [2024-03-25 20:45:48.104] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20
[info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000008
# [2024-03-25 20:47:05.240] [info] Simulating optical element 1/4
# [2024-03-25 20:47:11.722] [info] Elapsed time for optical element: 6482.268 ms
# [2024-03-25 20:47:11.722] [info] Simulating optical element 2/4
# [2024-03-25 20:47:11.747] [info] Elapsed time for optical element: 24.672256 ms
# [2024-03-25 20:47:11.769] [info] Simulating optical element 3/4
# [2024-03-25 20:47:12.079] [info] Elapsed time for optical element: 309.42905 ms
# [2024-03-25 20:47:12.104] [info] Simulating optical element 4/4
# [2024-03-25 20:47:13.274] [info] Elapsed time for optical element: 1169.2263 ms
# [2024-03-25 20:47:13.275] [info] Running phase step 2/5
# [2024-03-25 20:47:13.277] [info] Simulating optical element 4/4
# [2024-03-25 20:47:14.485] [info] Elapsed time for optical element: 1208.0885 ms
# [2024-03-25 20:47:14.486] [info] Running phase step 3/5
# [2024-03-25 20:47:14.488] [info] Simulating optical element 4/4
# [2024-03-25 20:47:15.679] [info] Elapsed time for optical element: 1190.7935 ms
# [2024-03-25 20:47:15.681] [info] Running phase step 4/5
# [2024-03-25 20:47:15.682] [info] Simulating optical element 4/4
# [2024-03-25 20:47:16.874] [info] Elapsed time for optical element: 1191.7102 ms
# [2024-03-25 20:47:16.876] [info] Running phase step 5/5
# [2024-03-25 20:47:16.876] [info] Simulating optical element 4/4
# [2024-03-25 20:47:18.051] [info] Elapsed time for optical element: 1175.3983 ms
# [2024-03-25 20:47:18.053] [info] Simulation finished in 13.222075904 seconds
# [2024-03-25 20:47:18.487] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000009
# [2024-03-25 20:47:18.867] [info] Simulating optical element 1/4
# [2024-03-25 20:47:25.471] [info] Elapsed time for optical element: 6603.31 ms
# [2024-03-25 20:47:25.471] [info] Simulating optical element 2/4
# [2024-03-25 20:47:25.496] [info] Elapsed time for optical element: 24.898016 ms
# [2024-03-25 20:47:25.519] [info] Simulating optical element 3/4
# [2024-03-25 20:47:25.831] [info] Elapsed time for optical element: 312.67267 ms
# [2024-03-25 20:47:25.857] [info] Simulating optical element 4/4
# [2024-03-25 20:47:27.046] [info] Elapsed time for optical element: 1189.4016 ms
# [2024-03-25 20:47:27.048] [info] Running phase step 2/5
# [2024-03-25 20:47:27.050] [info] Simulating optical element 4/4
# [2024-03-25 20:47:28.291] [info] Elapsed time for optical element: 1241.2411 ms
# [2024-03-25 20:47:28.292] [info] Running phase step 3/5
# [2024-03-25 20:47:28.294] [info] Simulating optical element 4/4
# [2024-03-25 20:47:29.504] [info] Elapsed time for optical element: 1209.9629 ms
# [2024-03-25 20:47:29.506] [info] Running phase step 4/5
# [2024-03-25 20:47:29.508] [info] Simulating optical element 4/4
# [2024-03-25 20:47:30.718] [info] Elapsed time for optical element: 1210.8656 ms
# [2024-03-25 20:47:30.720] [info] Running phase step 5/5
# [2024-03-25 20:47:30.720] [info] Simulating optical element 4/4
# [2024-03-25 20:47:31.916] [info] Elapsed time for optical element: 1195.8994 ms
# [2024-03-25 20:47:31.918] [info] Simulation finished in 13.43012579 seconds
# [2024-03-25 20:47:32.380] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000010
# [2024-03-25 20:47:32.799] [info] Simulating optical element 1/4
# [2024-03-25 20:47:39.441] [info] Elapsed time for optical element: 6642.1055 ms
# [2024-03-25 20:47:39.441] [info] Simulating optical element 2/4
# [2024-03-25 20:47:39.466] [info] Elapsed time for optical element: 24.772385 ms
# [2024-03-25 20:47:39.489] [info] Simulating optical element 3/4
# [2024-03-25 20:47:39.798] [info] Elapsed time for optical element: 308.633 ms
# [2024-03-25 20:47:39.823] [info] Simulating optical element 4/4
# [2024-03-25 20:47:41.035] [info] Elapsed time for optical element: 1211.7512 ms
# [2024-03-25 20:47:41.036] [info] Running phase step 2/5
# [2024-03-25 20:47:41.038] [info] Simulating optical element 4/4
# [2024-03-25 20:47:42.292] [info] Elapsed time for optical element: 1253.7699 ms
# [2024-03-25 20:47:42.293] [info] Running phase step 3/5
# [2024-03-25 20:47:42.295] [info] Simulating optical element 4/4
# [2024-03-25 20:47:43.524] [info] Elapsed time for optical element: 1229.0908 ms
# [2024-03-25 20:47:43.526] [info] Running phase step 4/5
# [2024-03-25 20:47:43.528] [info] Simulating optical element 4/4
# [2024-03-25 20:47:44.733] [info] Elapsed time for optical element: 1205.4708 ms
# [2024-03-25 20:47:44.735] [info] Running phase step 5/5
# [2024-03-25 20:47:44.735] [info] Simulating optical element 4/4
# [2024-03-25 20:47:45.927] [info] Elapsed time for optical element: 1192.3969 ms
# [2024-03-25 20:47:45.929] [info] Simulation finished in 13.547897334 seconds
# [2024-03-25 20:47:46.390] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000011
# [2024-03-25 20:47:46.781] [info] Simulating optical element 1/4
# [2024-03-25 20:47:53.400] [info] Elapsed time for optical element: 6618.7363 ms
# [2024-03-25 20:47:53.400] [info] Simulating optical element 2/4
# [2024-03-25 20:47:53.425] [info] Elapsed time for optical element: 24.969215 ms
# [2024-03-25 20:47:53.448] [info] Simulating optical element 3/4
# [2024-03-25 20:47:53.763] [info] Elapsed time for optical element: 314.9353 ms
# [2024-03-25 20:47:53.789] [info] Simulating optical element 4/4
# [2024-03-25 20:47:55.042] [info] Elapsed time for optical element: 1253.1337 ms
# [2024-03-25 20:47:55.043] [info] Running phase step 2/5
# [2024-03-25 20:47:55.045] [info] Simulating optical element 4/4
# [2024-03-25 20:47:56.247] [info] Elapsed time for optical element: 1202.1887 ms
# [2024-03-25 20:47:56.249] [info] Running phase step 3/5
# [2024-03-25 20:47:56.251] [info] Simulating optical element 4/4
# [2024-03-25 20:47:57.492] [info] Elapsed time for optical element: 1241.3513 ms
# [2024-03-25 20:47:57.494] [info] Running phase step 4/5
# [2024-03-25 20:47:57.495] [info] Simulating optical element 4/4
# [2024-03-25 20:47:58.734] [info] Elapsed time for optical element: 1238.4514 ms
# [2024-03-25 20:47:58.735] [info] Running phase step 5/5
# [2024-03-25 20:47:58.735] [info] Simulating optical element 4/4
# [2024-03-25 20:47:59.962] [info] Elapsed time for optical element: 1226.4338 ms
# [2024-03-25 20:47:59.964] [info] Simulation finished in 13.572857641 seconds
# [2024-03-25 20:48:00.420] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000012
# [2024-03-25 20:48:00.834] [info] Simulating optical element 1/4
# [2024-03-25 20:48:07.456] [info] Elapsed time for optical element: 6622.1777 ms
# [2024-03-25 20:48:07.456] [info] Simulating optical element 2/4
# [2024-03-25 20:48:07.481] [info] Elapsed time for optical element: 24.595936 ms
# [2024-03-25 20:48:07.503] [info] Simulating optical element 3/4
# [2024-03-25 20:48:07.810] [info] Elapsed time for optical element: 306.8016 ms
# [2024-03-25 20:48:07.836] [info] Simulating optical element 4/4
# [2024-03-25 20:48:09.029] [info] Elapsed time for optical element: 1193.5334 ms
# [2024-03-25 20:48:09.031] [info] Running phase step 2/5
# [2024-03-25 20:48:09.033] [info] Simulating optical element 4/4
# [2024-03-25 20:48:10.240] [info] Elapsed time for optical element: 1207.0942 ms
# [2024-03-25 20:48:10.241] [info] Running phase step 3/5
# [2024-03-25 20:48:10.243] [info] Simulating optical element 4/4
# [2024-03-25 20:48:11.451] [info] Elapsed time for optical element: 1208.1162 ms
# [2024-03-25 20:48:11.453] [info] Running phase step 4/5
# [2024-03-25 20:48:11.454] [info] Simulating optical element 4/4
# [2024-03-25 20:48:12.661] [info] Elapsed time for optical element: 1206.1177 ms
# [2024-03-25 20:48:12.662] [info] Running phase step 5/5
# [2024-03-25 20:48:12.662] [info] Simulating optical element 4/4
# [2024-03-25 20:48:13.856] [info] Elapsed time for optical element: 1194.1788 ms
# [2024-03-25 20:48:13.858] [info] Simulation finished in 13.4367697 seconds
# [2024-03-25 20:48:14.299] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000013
# [2024-03-25 20:48:14.713] [info] Simulating optical element 1/4
# [2024-03-25 20:48:21.444] [info] Elapsed time for optical element: 6730.705 ms
# [2024-03-25 20:48:21.444] [info] Simulating optical element 2/4
# [2024-03-25 20:48:21.469] [info] Elapsed time for optical element: 25.096416 ms
# [2024-03-25 20:48:21.492] [info] Simulating optical element 3/4
# [2024-03-25 20:48:21.837] [info] Elapsed time for optical element: 344.84772 ms
# [2024-03-25 20:48:21.865] [info] Simulating optical element 4/4
# [2024-03-25 20:48:23.157] [info] Elapsed time for optical element: 1291.4602 ms
# [2024-03-25 20:48:23.158] [info] Running phase step 2/5
# [2024-03-25 20:48:23.160] [info] Simulating optical element 4/4
# [2024-03-25 20:48:24.448] [info] Elapsed time for optical element: 1288.4459 ms
# [2024-03-25 20:48:24.450] [info] Running phase step 3/5
# [2024-03-25 20:48:24.452] [info] Simulating optical element 4/4
# [2024-03-25 20:48:25.742] [info] Elapsed time for optical element: 1290.0764 ms
# [2024-03-25 20:48:25.743] [info] Running phase step 4/5
# [2024-03-25 20:48:25.745] [info] Simulating optical element 4/4
# [2024-03-25 20:48:27.034] [info] Elapsed time for optical element: 1289.2775 ms
# [2024-03-25 20:48:27.036] [info] Running phase step 5/5
# [2024-03-25 20:48:27.036] [info] Simulating optical element 4/4
# [2024-03-25 20:48:28.316] [info] Elapsed time for optical element: 1280.0999 ms
# [2024-03-25 20:48:28.318] [info] Simulation finished in 14.018428548 seconds
# [2024-03-25 20:48:28.762] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000014
# [2024-03-25 20:48:29.173] [info] Simulating optical element 1/4
# [2024-03-25 20:48:35.975] [info] Elapsed time for optical element: 6802.0396 ms
# [2024-03-25 20:48:35.975] [info] Simulating optical element 2/4
# [2024-03-25 20:48:36.000] [info] Elapsed time for optical element: 24.631071 ms
# [2024-03-25 20:48:36.022] [info] Simulating optical element 3/4
# [2024-03-25 20:48:36.338] [info] Elapsed time for optical element: 315.6972 ms
# [2024-03-25 20:48:36.363] [info] Simulating optical element 4/4
# [2024-03-25 20:48:37.558] [info] Elapsed time for optical element: 1194.3959 ms
# [2024-03-25 20:48:37.559] [info] Running phase step 2/5
# [2024-03-25 20:48:37.561] [info] Simulating optical element 4/4
# [2024-03-25 20:48:38.798] [info] Elapsed time for optical element: 1237.1073 ms
# [2024-03-25 20:48:38.800] [info] Running phase step 3/5
# [2024-03-25 20:48:38.802] [info] Simulating optical element 4/4
# [2024-03-25 20:48:40.042] [info] Elapsed time for optical element: 1240.3317 ms
# [2024-03-25 20:48:40.044] [info] Running phase step 4/5
# [2024-03-25 20:48:40.045] [info] Simulating optical element 4/4
# [2024-03-25 20:48:41.283] [info] Elapsed time for optical element: 1237.1475 ms
# [2024-03-25 20:48:41.284] [info] Running phase step 5/5
# [2024-03-25 20:48:41.284] [info] Simulating optical element 4/4
# [2024-03-25 20:48:42.514] [info] Elapsed time for optical element: 1229.8738 ms
# [2024-03-25 20:48:42.516] [info] Simulation finished in 13.753769685 seconds
# [2024-03-25 20:48:42.982] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000015
# [2024-03-25 20:48:43.382] [info] Simulating optical element 1/4
# [2024-03-25 20:48:50.284] [info] Elapsed time for optical element: 6902.8174 ms
# [2024-03-25 20:48:50.284] [info] Simulating optical element 2/4
# [2024-03-25 20:48:50.310] [info] Elapsed time for optical element: 25.094208 ms
# [2024-03-25 20:48:50.333] [info] Simulating optical element 3/4
# [2024-03-25 20:48:50.663] [info] Elapsed time for optical element: 330.28104 ms
# [2024-03-25 20:48:50.690] [info] Simulating optical element 4/4
# [2024-03-25 20:48:51.965] [info] Elapsed time for optical element: 1274.3846 ms
# [2024-03-25 20:48:51.966] [info] Running phase step 2/5
# [2024-03-25 20:48:51.968] [info] Simulating optical element 4/4
# [2024-03-25 20:48:53.242] [info] Elapsed time for optical element: 1273.983 ms
# [2024-03-25 20:48:53.243] [info] Running phase step 3/5
# [2024-03-25 20:48:53.245] [info] Simulating optical element 4/4
# [2024-03-25 20:48:54.518] [info] Elapsed time for optical element: 1272.949 ms
# [2024-03-25 20:48:54.520] [info] Running phase step 4/5
# [2024-03-25 20:48:54.522] [info] Simulating optical element 4/4
# [2024-03-25 20:48:55.790] [info] Elapsed time for optical element: 1268.5721 ms
# [2024-03-25 20:48:55.792] [info] Running phase step 5/5
# [2024-03-25 20:48:55.792] [info] Simulating optical element 4/4
# [2024-03-25 20:48:57.056] [info] Elapsed time for optical element: 1263.9126 ms
# [2024-03-25 20:48:57.058] [info] Simulation finished in 14.073923134 seconds
# [2024-03-25 20:48:57.519] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20
[info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000018
# [2024-03-25 20:49:27.680] [info] Simulating optical element 1/4
# [2024-03-25 20:49:34.663] [info] Elapsed time for optical element: 6982.983 ms
# [2024-03-25 20:49:34.663] [info] Simulating optical element 2/4
# [2024-03-25 20:49:34.688] [info] Elapsed time for optical element: 24.6008 ms
# [2024-03-25 20:49:34.711] [info] Simulating optical element 3/4
# [2024-03-25 20:49:35.086] [info] Elapsed time for optical element: 375.2746 ms
# [2024-03-25 20:49:35.119] [info] Simulating optical element 4/4
# [2024-03-25 20:49:36.532] [info] Elapsed time for optical element: 1413.1658 ms
# [2024-03-25 20:49:36.534] [info] Running phase step 2/5
# [2024-03-25 20:49:36.536] [info] Simulating optical element 4/4
# [2024-03-25 20:49:37.796] [info] Elapsed time for optical element: 1260.0599 ms
# [2024-03-25 20:49:37.797] [info] Running phase step 3/5
# [2024-03-25 20:49:37.799] [info] Simulating optical element 4/4
# [2024-03-25 20:49:39.062] [info] Elapsed time for optical element: 1262.8347 ms
# [2024-03-25 20:49:39.063] [info] Running phase step 4/5
# [2024-03-25 20:49:39.065] [info] Simulating optical element 4/4
# [2024-03-25 20:49:40.328] [info] Elapsed time for optical element: 1262.3867 ms
# [2024-03-25 20:49:40.329] [info] Running phase step 5/5
# [2024-03-25 20:49:40.329] [info] Simulating optical element 4/4
# [2024-03-25 20:49:41.585] [info] Elapsed time for optical element: 1255.9293 ms
# [2024-03-25 20:49:41.587] [info] Simulation finished in 14.317706108 seconds
# [2024-03-25 20:49:42.027] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000019
# [2024-03-25 20:49:42.441] [info] Simulating optical element 1/4
# [2024-03-25 20:49:49.524] [info] Elapsed time for optical element: 7083.1367 ms
# [2024-03-25 20:49:49.524] [info] Simulating optical element 2/4
# [2024-03-25 20:49:49.550] [info] Elapsed time for optical element: 25.231104 ms
# [2024-03-25 20:49:49.573] [info] Simulating optical element 3/4
# [2024-03-25 20:49:49.893] [info] Elapsed time for optical element: 320.28262 ms
# [2024-03-25 20:49:49.919] [info] Simulating optical element 4/4
# [2024-03-25 20:49:51.385] [info] Elapsed time for optical element: 1465.2804 ms
# [2024-03-25 20:49:51.386] [info] Running phase step 2/5
# [2024-03-25 20:49:51.388] [info] Simulating optical element 4/4
# [2024-03-25 20:49:52.693] [info] Elapsed time for optical element: 1304.7206 ms
# [2024-03-25 20:49:52.694] [info] Running phase step 3/5
# [2024-03-25 20:49:52.696] [info] Simulating optical element 4/4
# [2024-03-25 20:49:54.004] [info] Elapsed time for optical element: 1308.0984 ms
# [2024-03-25 20:49:54.006] [info] Running phase step 4/5
# [2024-03-25 20:49:54.008] [info] Simulating optical element 4/4
# [2024-03-25 20:49:55.304] [info] Elapsed time for optical element: 1296.2236 ms
# [2024-03-25 20:49:55.306] [info] Running phase step 5/5
# [2024-03-25 20:49:55.306] [info] Simulating optical element 4/4
# [2024-03-25 20:49:56.604] [info] Elapsed time for optical element: 1298.5532 ms
# [2024-03-25 20:49:56.606] [info] Simulation finished in 14.578298105 seconds
# [2024-03-25 20:49:57.049] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000020
# [2024-03-25 20:49:57.467] [info] Simulating optical element 1/4
# [2024-03-25 20:50:04.566] [info] Elapsed time for optical element: 7099.121 ms
# [2024-03-25 20:50:04.566] [info] Simulating optical element 2/4
# [2024-03-25 20:50:04.592] [info] Elapsed time for optical element: 25.862144 ms
# [2024-03-25 20:50:04.616] [info] Simulating optical element 3/4
# [2024-03-25 20:50:04.956] [info] Elapsed time for optical element: 340.94818 ms
# [2024-03-25 20:50:04.991] [info] Simulating optical element 4/4
# [2024-03-25 20:50:06.541] [info] Elapsed time for optical element: 1549.8209 ms
# [2024-03-25 20:50:06.542] [info] Running phase step 2/5
# [2024-03-25 20:50:06.544] [info] Simulating optical element 4/4
# [2024-03-25 20:50:07.917] [info] Elapsed time for optical element: 1372.7987 ms
# [2024-03-25 20:50:07.919] [info] Running phase step 3/5
# [2024-03-25 20:50:07.921] [info] Simulating optical element 4/4
# [2024-03-25 20:50:09.273] [info] Elapsed time for optical element: 1352.9087 ms
# [2024-03-25 20:50:09.275] [info] Running phase step 4/5
# [2024-03-25 20:50:09.277] [info] Simulating optical element 4/4
# [2024-03-25 20:50:10.592] [info] Elapsed time for optical element: 1314.8754 ms
# [2024-03-25 20:50:10.593] [info] Running phase step 5/5
# [2024-03-25 20:50:10.593] [info] Simulating optical element 4/4
# [2024-03-25 20:50:11.900] [info] Elapsed time for optical element: 1307.1649 ms
# [2024-03-25 20:50:11.903] [info] Simulation finished in 14.852800359 seconds
# [2024-03-25 20:50:12.237] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000021
# [2024-03-25 20:50:12.562] [info] Simulating optical element 1/4
# [2024-03-25 20:50:19.714] [info] Elapsed time for optical element: 7151.716 ms
# [2024-03-25 20:50:19.714] [info] Simulating optical element 2/4
# [2024-03-25 20:50:19.740] [info] Elapsed time for optical element: 26.29808 ms
# [2024-03-25 20:50:19.764] [info] Simulating optical element 3/4
# [2024-03-25 20:50:20.116] [info] Elapsed time for optical element: 351.5846 ms
# [2024-03-25 20:50:20.149] [info] Simulating optical element 4/4
# [2024-03-25 20:50:21.715] [info] Elapsed time for optical element: 1565.5629 ms
# [2024-03-25 20:50:21.717] [info] Running phase step 2/5
# [2024-03-25 20:50:21.719] [info] Simulating optical element 4/4
# [2024-03-25 20:50:23.086] [info] Elapsed time for optical element: 1367.894 ms
# [2024-03-25 20:50:23.088] [info] Running phase step 3/5
# [2024-03-25 20:50:23.090] [info] Simulating optical element 4/4
# [2024-03-25 20:50:24.459] [info] Elapsed time for optical element: 1369.0955 ms
# [2024-03-25 20:50:24.460] [info] Running phase step 4/5
# [2024-03-25 20:50:24.462] [info] Simulating optical element 4/4
# [2024-03-25 20:50:25.835] [info] Elapsed time for optical element: 1372.6274 ms
# [2024-03-25 20:50:25.836] [info] Running phase step 5/5
# [2024-03-25 20:50:25.836] [info] Simulating optical element 4/4
# [2024-03-25 20:50:27.198] [info] Elapsed time for optical element: 1361.4381 ms
# [2024-03-25 20:50:27.200] [info] Simulation finished in 14.961997671 seconds
# [2024-03-25 20:50:27.644] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000022
# [2024-03-25 20:50:28.062] [info] Simulating optical element 1/4
# [2024-03-25 20:50:35.195] [info] Elapsed time for optical element: 7132.8823 ms
# [2024-03-25 20:50:35.195] [info] Simulating optical element 2/4
# [2024-03-25 20:50:35.220] [info] Elapsed time for optical element: 25.086016 ms
# [2024-03-25 20:50:35.243] [info] Simulating optical element 3/4
# [2024-03-25 20:50:35.568] [info] Elapsed time for optical element: 324.85114 ms
# [2024-03-25 20:50:35.594] [info] Simulating optical element 4/4
# [2024-03-25 20:50:36.902] [info] Elapsed time for optical element: 1308.5675 ms
# [2024-03-25 20:50:36.904] [info] Running phase step 2/5
# [2024-03-25 20:50:36.906] [info] Simulating optical element 4/4
# [2024-03-25 20:50:38.238] [info] Elapsed time for optical element: 1332.248 ms
# [2024-03-25 20:50:38.240] [info] Running phase step 3/5
# [2024-03-25 20:50:38.242] [info] Simulating optical element 4/4
# [2024-03-25 20:50:39.568] [info] Elapsed time for optical element: 1326.78 ms
# [2024-03-25 20:50:39.570] [info] Running phase step 4/5
# [2024-03-25 20:50:39.572] [info] Simulating optical element 4/4
# [2024-03-25 20:50:40.896] [info] Elapsed time for optical element: 1324.1978 ms
# [2024-03-25 20:50:40.898] [info] Running phase step 5/5
# [2024-03-25 20:50:40.898] [info] Simulating optical element 4/4
# [2024-03-25 20:50:42.217] [info] Elapsed time for optical element: 1319.5327 ms
# [2024-03-25 20:50:42.219] [info] Simulation finished in 14.574929 seconds
# [2024-03-25 20:50:42.528] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000023
# [2024-03-25 20:50:42.944] [info] Simulating optical element 1/4
# [2024-03-25 20:50:50.214] [info] Elapsed time for optical element: 7270.062 ms
# [2024-03-25 20:50:50.214] [info] Simulating optical element 2/4
# [2024-03-25 20:50:50.240] [info] Elapsed time for optical element: 25.828417 ms
# [2024-03-25 20:50:50.264] [info] Simulating optical element 3/4
# [2024-03-25 20:50:50.607] [info] Elapsed time for optical element: 343.1547 ms
# [2024-03-25 20:50:50.635] [info] Simulating optical element 4/4
# [2024-03-25 20:50:51.927] [info] Elapsed time for optical element: 1292.0073 ms
# [2024-03-25 20:50:51.928] [info] Running phase step 2/5
# [2024-03-25 20:50:51.930] [info] Simulating optical element 4/4
# [2024-03-25 20:50:53.544] [info] Elapsed time for optical element: 1613.5973 ms
# [2024-03-25 20:50:53.546] [info] Running phase step 3/5
# [2024-03-25 20:50:53.548] [info] Simulating optical element 4/4
# [2024-03-25 20:50:54.929] [info] Elapsed time for optical element: 1380.784 ms
# [2024-03-25 20:50:54.930] [info] Running phase step 4/5
# [2024-03-25 20:50:54.932] [info] Simulating optical element 4/4
# [2024-03-25 20:50:56.263] [info] Elapsed time for optical element: 1331.2034 ms
# [2024-03-25 20:50:56.265] [info] Running phase step 5/5
# [2024-03-25 20:50:56.265] [info] Simulating optical element 4/4
# [2024-03-25 20:50:57.592] [info] Elapsed time for optical element: 1327.0856 ms
# [2024-03-25 20:50:57.594] [info] Simulation finished in 15.065209956 seconds
# [2024-03-25 20:50:57.880] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20
[info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000030
# [2024-03-25 20:52:30.676] [info] Simulating optical element 1/4
# [2024-03-25 20:52:37.923] [info] Elapsed time for optical element: 7246.8335 ms
# [2024-03-25 20:52:37.923] [info] Simulating optical element 2/4
# [2024-03-25 20:52:37.948] [info] Elapsed time for optical element: 25.265888 ms
# [2024-03-25 20:52:37.972] [info] Simulating optical element 3/4
# [2024-03-25 20:52:38.311] [info] Elapsed time for optical element: 339.0812 ms
# [2024-03-25 20:52:38.338] [info] Simulating optical element 4/4
# [2024-03-25 20:52:39.761] [info] Elapsed time for optical element: 1422.9258 ms
# [2024-03-25 20:52:39.763] [info] Running phase step 2/5
# [2024-03-25 20:52:39.765] [info] Simulating optical element 4/4
# ...
# [2024-03-25 21:15:12.518] [info] Simulating optical element 4/4
# [2024-03-25 21:15:14.293] [info] Elapsed time for optical element: 1774.796 ms
# [2024-03-25 21:15:14.295] [info] Running phase step 4/5
# [2024-03-25 21:15:14.297] [info] Simulating optical element 4/4
# [2024-03-25 21:15:15.948] [info] Elapsed time for optical element: 1651.0017 ms
# [2024-03-25 21:15:15.950] [info] Running phase step 5/5
# [2024-03-25 21:15:15.950] [info] Simulating optical element 4/4
# [2024-03-25 21:15:17.598] [info] Elapsed time for optical element: 1647.7936 ms
# [2024-03-25 21:15:17.600] [info] Simulation finished in 17.672032619 seconds
# [2024-03-25 21:15:17.842] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000109
# [2024-03-25 21:15:18.177] [info] Simulating optical element 1/4
# [2024-03-25 21:15:26.172] [info] Elapsed time for optical element: 7995.0273 ms
# [2024-03-25 21:15:26.172] [info] Simulating optical element 2/4
# [2024-03-25 21:15:26.202] [info] Elapsed time for optical element: 30.22032 ms
# [2024-03-25 21:15:26.230] [info] Simulating optical element 3/4
# [2024-03-25 21:15:26.656] [info] Elapsed time for optical element: 425.46844 ms
# [2024-03-25 21:15:26.690] [info] Simulating optical element 4/4
# [2024-03-25 21:15:28.310] [info] Elapsed time for optical element: 1619.3718 ms
# [2024-03-25 21:15:28.311] [info] Running phase step 2/5
# [2024-03-25 21:15:28.313] [info] Simulating optical element 4/4
# [2024-03-25 21:15:29.941] [info] Elapsed time for optical element: 1628.1725 ms
# [2024-03-25 21:15:29.943] [info] Running phase step 3/5
# [2024-03-25 21:15:29.945] [info] Simulating optical element 4/4
# [2024-03-25 21:15:31.582] [info] Elapsed time for optical element: 1636.6982 ms
# [2024-03-25 21:15:31.584] [info] Running phase step 4/5
# [2024-03-25 21:15:31.586] [info] Simulating optical element 4/4
# [2024-03-25 21:15:33.483] [info] Elapsed time for optical element: 1897.2283 ms
# [2024-03-25 21:15:33.485] [info] Running phase step 5/5
# [2024-03-25 21:15:33.485] [info] Simulating optical element 4/4
# [2024-03-25 21:15:35.383] [info] Elapsed time for optical element: 1898.4612 ms
# [2024-03-25 21:15:35.386] [info] Simulation finished in 17.5429754 seconds
# [2024-03-25 21:15:35.626] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000110
# [2024-03-25 21:15:35.951] [info] Simulating optical element 1/4
# [2024-03-25 21:15:43.790] [info] Elapsed time for optical element: 7838.5786 ms
# [2024-03-25 21:15:43.790] [info] Simulating optical element 2/4
# [2024-03-25 21:15:43.818] [info] Elapsed time for optical element: 27.896223 ms
# [2024-03-25 21:15:43.844] [info] Simulating optical element 3/4
# [2024-03-25 21:15:44.218] [info] Elapsed time for optical element: 374.13766 ms
# [2024-03-25 21:15:44.247] [info] Simulating optical element 4/4
# [2024-03-25 21:15:46.218] [info] Elapsed time for optical element: 1970.6392 ms
# [2024-03-25 21:15:46.219] [info] Running phase step 2/5
# [2024-03-25 21:15:46.221] [info] Simulating optical element 4/4
# [2024-03-25 21:15:47.510] [info] Elapsed time for optical element: 1288.2555 ms
# [2024-03-25 21:15:47.511] [info] Running phase step 3/5
# [2024-03-25 21:15:47.513] [info] Simulating optical element 4/4
# [2024-03-25 21:15:49.663] [info] Elapsed time for optical element: 2149.336 ms
# [2024-03-25 21:15:49.664] [info] Running phase step 4/5
# [2024-03-25 21:15:49.666] [info] Simulating optical element 4/4
# [2024-03-25 21:15:51.693] [info] Elapsed time for optical element: 2027.2128 ms
# [2024-03-25 21:15:51.695] [info] Running phase step 5/5
# [2024-03-25 21:15:51.695] [info] Simulating optical element 4/4
# [2024-03-25 21:15:53.647] [info] Elapsed time for optical element: 1951.9124 ms
# [2024-03-25 21:15:53.649] [info] Simulation finished in 18.021737531 seconds
# [2024-03-25 21:15:53.886] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000111
# [2024-03-25 21:15:54.213] [info] Simulating optical element 1/4
# [2024-03-25 21:16:01.898] [info] Elapsed time for optical element: 7684.5977 ms
# [2024-03-25 21:16:01.898] [info] Simulating optical element 2/4
# [2024-03-25 21:16:01.925] [info] Elapsed time for optical element: 27.323584 ms
# [2024-03-25 21:16:01.951] [info] Simulating optical element 3/4
# [2024-03-25 21:16:02.327] [info] Elapsed time for optical element: 376.222 ms
# [2024-03-25 21:16:02.357] [info] Simulating optical element 4/4
# [2024-03-25 21:16:04.240] [info] Elapsed time for optical element: 1882.6685 ms
# [2024-03-25 21:16:04.241] [info] Running phase step 2/5
# [2024-03-25 21:16:04.243] [info] Simulating optical element 4/4
# [2024-03-25 21:16:05.802] [info] Elapsed time for optical element: 1558.3141 ms
# [2024-03-25 21:16:05.803] [info] Running phase step 3/5
# [2024-03-25 21:16:05.805] [info] Simulating optical element 4/4
# [2024-03-25 21:16:07.383] [info] Elapsed time for optical element: 1577.7073 ms
# [2024-03-25 21:16:07.385] [info] Running phase step 4/5
# [2024-03-25 21:16:07.387] [info] Simulating optical element 4/4
# [2024-03-25 21:16:08.961] [info] Elapsed time for optical element: 1573.89 ms
# [2024-03-25 21:16:08.963] [info] Running phase step 5/5
# [2024-03-25 21:16:08.963] [info] Simulating optical element 4/4
# [2024-03-25 21:16:10.806] [info] Elapsed time for optical element: 1843.5217 ms
# [2024-03-25 21:16:10.813] [info] Simulation finished in 16.926386055 seconds
# [2024-03-25 21:16:11.055] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20
[info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000114
# [2024-03-25 21:16:46.748] [info] Simulating optical element 1/4
# [2024-03-25 21:16:54.625] [info] Elapsed time for optical element: 7876.346 ms
# [2024-03-25 21:16:54.625] [info] Simulating optical element 2/4
# [2024-03-25 21:16:54.653] [info] Elapsed time for optical element: 27.740768 ms
# [2024-03-25 21:16:54.680] [info] Simulating optical element 3/4
# [2024-03-25 21:16:55.050] [info] Elapsed time for optical element: 369.78506 ms
# [2024-03-25 21:16:55.080] [info] Simulating optical element 4/4
# [2024-03-25 21:16:57.196] [info] Elapsed time for optical element: 2116.2888 ms
# [2024-03-25 21:16:57.198] [info] Running phase step 2/5
# [2024-03-25 21:16:57.200] [info] Simulating optical element 4/4
# [2024-03-25 21:16:58.618] [info] Elapsed time for optical element: 1418.5963 ms
# [2024-03-25 21:16:58.621] [info] Running phase step 3/5
# [2024-03-25 21:16:58.623] [info] Simulating optical element 4/4
# [2024-03-25 21:17:00.663] [info] Elapsed time for optical element: 2040.6149 ms
# [2024-03-25 21:17:00.665] [info] Running phase step 4/5
# [2024-03-25 21:17:00.667] [info] Simulating optical element 4/4
# [2024-03-25 21:17:02.302] [info] Elapsed time for optical element: 1634.9941 ms
# [2024-03-25 21:17:02.304] [info] Running phase step 5/5
# [2024-03-25 21:17:02.304] [info] Simulating optical element 4/4
# [2024-03-25 21:17:03.932] [info] Elapsed time for optical element: 1627.3102 ms
# [2024-03-25 21:17:03.934] [info] Simulation finished in 17.511289683 seconds
# [2024-03-25 21:17:04.175] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000115
# [2024-03-25 21:17:04.506] [info] Simulating optical element 1/4
# [2024-03-25 21:17:12.441] [info] Elapsed time for optical element: 7934.882 ms
# [2024-03-25 21:17:12.441] [info] Simulating optical element 2/4
# [2024-03-25 21:17:12.468] [info] Elapsed time for optical element: 27.617216 ms
# [2024-03-25 21:17:12.496] [info] Simulating optical element 3/4
# [2024-03-25 21:17:12.868] [info] Elapsed time for optical element: 371.96304 ms
# [2024-03-25 21:17:12.898] [info] Simulating optical element 4/4
# [2024-03-25 21:17:14.894] [info] Elapsed time for optical element: 1996.4559 ms
# [2024-03-25 21:17:14.896] [info] Running phase step 2/5
# [2024-03-25 21:17:14.898] [info] Simulating optical element 4/4
# [2024-03-25 21:17:16.349] [info] Elapsed time for optical element: 1451.1472 ms
# [2024-03-25 21:17:16.351] [info] Running phase step 3/5
# [2024-03-25 21:17:16.353] [info] Simulating optical element 4/4
# [2024-03-25 21:17:18.429] [info] Elapsed time for optical element: 2076.8665 ms
# [2024-03-25 21:17:18.431] [info] Running phase step 4/5
# [2024-03-25 21:17:18.433] [info] Simulating optical element 4/4
# [2024-03-25 21:17:20.010] [info] Elapsed time for optical element: 1576.6467 ms
# [2024-03-25 21:17:20.012] [info] Running phase step 5/5
# [2024-03-25 21:17:20.012] [info] Simulating optical element 4/4
# [2024-03-25 21:17:21.978] [info] Elapsed time for optical element: 1966.6088 ms
# [2024-03-25 21:17:21.981] [info] Simulation finished in 17.805422764 seconds
# [2024-03-25 21:17:22.221] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000116
# [2024-03-25 21:17:22.550] [info] Simulating optical element 1/4
# [2024-03-25 21:17:30.564] [info] Elapsed time for optical element: 8014.592 ms
# [2024-03-25 21:17:30.564] [info] Simulating optical element 2/4
# [2024-03-25 21:17:30.593] [info] Elapsed time for optical element: 28.428 ms
# [2024-03-25 21:17:30.621] [info] Simulating optical element 3/4
# [2024-03-25 21:17:31.010] [info] Elapsed time for optical element: 389.28925 ms
# [2024-03-25 21:17:31.041] [info] Simulating optical element 4/4
# [2024-03-25 21:17:32.886] [info] Elapsed time for optical element: 1845.5128 ms
# [2024-03-25 21:17:32.893] [info] Running phase step 2/5
# [2024-03-25 21:17:32.897] [info] Simulating optical element 4/4
# [2024-03-25 21:17:34.492] [info] Elapsed time for optical element: 1595.2484 ms
# [2024-03-25 21:17:34.494] [info] Running phase step 3/5
# [2024-03-25 21:17:34.496] [info] Simulating optical element 4/4
# [2024-03-25 21:17:36.073] [info] Elapsed time for optical element: 1577.6176 ms
# [2024-03-25 21:17:36.075] [info] Running phase step 4/5
# [2024-03-25 21:17:36.077] [info] Simulating optical element 4/4
# [2024-03-25 21:17:37.728] [info] Elapsed time for optical element: 1650.6737 ms
# [2024-03-25 21:17:37.729] [info] Running phase step 5/5
# [2024-03-25 21:17:37.729] [info] Simulating optical element 4/4
# [2024-03-25 21:17:39.382] [info] Elapsed time for optical element: 1652.7644 ms
# [2024-03-25 21:17:39.384] [info] Simulation finished in 17.162998448 seconds
# [2024-03-25 21:17:39.622] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000117
# [2024-03-25 21:17:39.941] [info] Simulating optical element 1/4
# [2024-03-25 21:17:47.878] [info] Elapsed time for optical element: 7936.361 ms
# [2024-03-25 21:17:47.878] [info] Simulating optical element 2/4
# [2024-03-25 21:17:47.909] [info] Elapsed time for optical element: 31.301632 ms
# [2024-03-25 21:17:47.942] [info] Simulating optical element 3/4
# [2024-03-25 21:17:48.547] [info] Elapsed time for optical element: 604.92975 ms
# [2024-03-25 21:17:48.595] [info] Simulating optical element 4/4
# [2024-03-25 21:17:50.630] [info] Elapsed time for optical element: 2034.9502 ms
# [2024-03-25 21:17:50.632] [info] Running phase step 2/5
# [2024-03-25 21:17:50.634] [info] Simulating optical element 4/4
# [2024-03-25 21:17:52.330] [info] Elapsed time for optical element: 1695.3324 ms
# [2024-03-25 21:17:52.331] [info] Running phase step 3/5
# [2024-03-25 21:17:52.333] [info] Simulating optical element 4/4
# [2024-03-25 21:17:54.016] [info] Elapsed time for optical element: 1683.0546 ms
# [2024-03-25 21:17:54.018] [info] Running phase step 4/5
# [2024-03-25 21:17:54.020] [info] Simulating optical element 4/4
# [2024-03-25 21:17:55.703] [info] Elapsed time for optical element: 1683.018 ms
# [2024-03-25 21:17:55.705] [info] Running phase step 5/5
# [2024-03-25 21:17:55.705] [info] Simulating optical element 4/4
# [2024-03-25 21:17:57.366] [info] Elapsed time for optical element: 1661.629 ms
# [2024-03-25 21:17:57.369] [info] Simulation finished in 17.746014807 seconds
# [2024-03-25 21:17:57.591] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240325_204521593776/00000118
# [2024-03-25 21:17:57.894] [info] Simulating optical element 1/4
# [2024-03-25 21:18:05.793] [info] Elapsed time for optical element: 7898.831 ms
# [2024-03-25 21:18:05.793] [info] Simulating optical element 2/4
# [2024-03-25 21:18:05.820] [info] Elapsed time for optical element: 27.632511 ms
# [2024-03-25 21:18:05.847] [info] Simulating optical element 3/4
# [2024-03-25 21:18:06.240] [info] Elapsed time for optical element: 392.39044 ms
# [2024-03-25 21:18:06.271] [info] Simulating optical element 4/4
# [2024-03-25 21:18:08.203] [info] Elapsed time for optical element: 1931.6191 ms
# [2024-03-25 21:18:08.206] [info] Running phase step 2/5
# [2024-03-25 21:18:08.208] [info] Simulating optical element 4/4
# [2024-03-25 21:18:09.742] [info] Elapsed time for optical element: 1534.3273 ms
# [2024-03-25 21:18:09.744] [info] Running phase step 3/5
# [2024-03-25 21:18:09.746] [info] Simulating optical element 4/4
# [2024-03-25 21:18:11.260] [info] Elapsed time for optical element: 1514.4126 ms
# [2024-03-25 21:18:11.262] [info] Running phase step 4/5
# [2024-03-25 21:18:11.264] [info] Simulating optical element 4/4

# %%
h0 = 180e-6

# %%
config_dict = {
        "sim_params": {
            "N": N,
            "dx": dx,
            "z_detector": z_g2 + 370e-6,
            "detector_size": 0.004,
            "detector_pixel_size_x": 1e-7,
            "detector_pixel_size_y": 1.0,
            "chunk_size": 256 * 1024 * 1024 // 16,  # use 256MB chunks
        },
        "use_disk_vector": False,
        "save_final_u_vectors": False,
        "dtype": "c8",
        "multisource": {
            "type": "points",
            "energy_range": [11000, 70000],
            "x_range": [-10e-6, 10e-6],
            "z": 0.0,
            "nr_source_points": 1000,
            "seed": 1,
            "spectrum": path_to_spectrum,
        },
        "elements": [
            {
                "type": "grating",
                "pitch": p0,
                "dc": [0.5, 0.5],
                "z_start": z_g0,
                "thickness": h0,
                "nr_steps": 30,
                "x_positions": [0.0],
                "substrate_thickness": 500*1e-6 - h0,
                "mat_a": ["C5H8O2", 1.19],
                "mat_b": ["Au", 19.32],
                "mat_substrate": ["C", 2.26],
            },
            {
                "type": "grating",
                "pitch": p1,
                "dc": [0.5, 0.5],
                "z_start": z_g1,
                "thickness": h1,
                "nr_steps": 10,
                "x_positions": [0.0],
                "substrate_thickness": 200 * 1e-6 - h1,
                "mat_a": ["Si", 2.34],
                "mat_b": None,
                "mat_substrate": ["Si", 2.34],
            },
            {
                "type": "sample",
                "z_start": z_g2,
                "pixel_size_x": dx_g2,
                "pixel_size_z": dz_g2,
                "grid_path": grid_path_g2,
                "materials": [["Au", 19.32], ["Si", 2.34]],
                "x_positions": (np.arange(5) * p2/5).tolist(),
            },
            {
                "type": "grating",
                "pitch": p2,
                "dc": [1.0, 1.0],
                "z_start": z_g2 + 147e-6,
                "thickness": 1e-10,
                "nr_steps": 0,
                "x_positions": (np.arange(5) * p2/5).tolist(),
                "substrate_thickness": 370*1e-6 - 147e-6,
                "mat_a": ["Si", 2.34],
                "mat_b": ["Si", 2.34],
                "mat_substrate": ["Si", 2.34],
            },
        ],
}

sim_path = multisim.setup_simulation(config_dict, Path("."), simulations_dir)

# %%
for i in range(1000):
    os.system(f"CUDA_VISIBLE_DEVICES=1 ../rave-sim/fast-wave/build-Release/fastwave -s {i} {sim_path}")
