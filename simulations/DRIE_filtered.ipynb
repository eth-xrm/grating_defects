# %%
# Copyright (c) 2025, ETH Zurich

# %%
import sys
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import os
import scipy.stats as stats
import scipy.ndimage
from tqdm import tqdm
import spekpy as spk
import h5py

from scipy import interpolate

# %%
rave_sim_dir = Path('../rave-sim').resolve()
simulations_dir = Path('<PATH_TO_STORE_SIMULATIONS>')
scratch_dir = simulations_dir


sys.path.insert(0, str(rave_sim_dir / "nist_lookup"))
from nist_lookup.xraydb_plugin import xray_delta_beta

# %%
sys.path.insert(0, str(rave_sim_dir / "big-wave"))
import multisim
import config
import util
import propagation

# %%
def calculate_G1_height(eng):
    # constants
    h = 6.62607004 * 10**(-34) # planck constant in mˆ2 kg / s
    c_0 = 299792458 # speed of light in m / s
    eV_to_joule = 1.602176634*10**(-19)
    N_A = 6.02214086 * 10**23 #[1/mol]
    
    lambda_ = h * c_0 / (eng*eV_to_joule)
    delta_diff = xray_delta_beta('Si', 2.34, eng)[0]
    height = np.pi  * lambda_ / (2*np.pi * delta_diff)

    return height


def signal_retrieval_least_squares(data, period=None, axis=-1):
    if axis != -1:
        data = np.moveaxis(data, axis, -1)

    nsteps = data.shape[-1]

    if period is None:
        period = nsteps

    phi = np.linspace(0, 2 * np.pi * nsteps / (period), nsteps, endpoint=False)
    M = np.c_[np.sin(phi), np.cos(phi), np.ones(nsteps)]
    res, chi2, _rank, _sing_vals = np.linalg.lstsq(M, data.reshape((-1, nsteps)).T, rcond=-1)

    res = res.T.reshape((*data.shape[:-1], -1))

    dabs = res[...,2]
    dphase = -np.arctan2(res[...,0], res[...,1])
    dvis = np.sqrt(res[...,0]**2 + res[...,1]**2) / dabs

    # normalization to the total number of counts
    dabs *= nsteps

    return dabs, dphase, dvis, np.nanmean(chi2)


def calculate_pixel_intensity(x, fringe, pxEdges, statistics = 'sum'):
    fringeStats = stats.binned_statistic(x, fringe, bins=pxEdges, statistic = statistics)
    return fringeStats.statistic

def perform_binned_signal_retrieval(x, wf, pxSize, nrSteps, plot_curve = True):
    leftSide = np.arange(0-pxSize/2, np.min(x), -pxSize)
    rightSide = np.arange(0 + pxSize/2, np.max(x), pxSize)
    pxEdges = np.concatenate([np.flip(leftSide), rightSide])
    int_px = []
    for i in range(nrSteps):
        int_px.append(calculate_pixel_intensity(x, wf[i,:], pxEdges))
    int_px = np.asarray(int_px)

    trans, phase, vis, _ = signal_retrieval_least_squares(int_px, period = nrSteps, axis = 0)
    if plot_curve:
        plot_curves(trans, phase, vis, pxEdges)
    return int_px, trans, phase, vis, pxEdges

def plot_curves(trans, phase, vis, pxEdges):

    fig, axs = plt.subplots(figsize=(15,6), sharex = True, nrows = 1, ncols = 2)
    axs[0].plot(pxEdges[1:], trans, label = 'Transmission')
    axs[0].set_title('Transmission')
    axs[1].plot(pxEdges[1:], vis, label = 'Visibility')
    axs[1].set_title('Visibility')

def perform_binning(x, wf, pxSize):
    leftSide = np.arange(0-pxSize/2, np.min(x), -pxSize)
    rightSide = np.arange(0 + pxSize/2, np.max(x), pxSize)
    pxEdges = np.concatenate([np.flip(leftSide), rightSide])
    int_px = calculate_pixel_intensity(x, wf, pxEdges, statistics = 'mean')
    return int_px


    #np.random.seed(1)
    
    sample_energy = np.random.choice(x, p=y)
    if sample_energy >= low_threshold:
        return True
    else:
        return False
    
    
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

def calculate_SNR(wavefronts, detector_x, phase_steps):
    summed_wf = np.zeros_like(wavefronts[0][0])
        
    for point in wavefronts:
        wf, x_point, eng = point
        
        summed_wf += wf

    return summed_wf

def get_subdict(dict_, idx):
    sub_dict = {}
    for key in dict_.keys():
        sub_dict[key] = dict_[key][idx]
    return sub_dict

def calc_Vis_theoretical(eng, Edes,m):
    V = 2/np.pi * np.abs(np.sin(np.pi / 2 * Edes / eng)**2 * np.sin(m * np.pi / 2 * Edes / eng))
    return V

def mu_h2o(eng):
    lambda_ = h * c_0 / (eng*eV_to_joule)
    beta = xray_delta_beta('H2O', 1.0, eng)[1]
    return 4 * np.pi / lambda_ * beta

# %%
calculate_G1_height(38000) * 1e6
# Out:
# 48.6133955033019

# %%
# constants
h = 6.62607004 * 10**(-34) # planck constant in mˆ2 kg / s
c_0 = 299792458 # speed of light in m / s
eV_to_joule = 1.602176634*10**(-19)
N_A = 6.02214086 * 10**23 #[1/mol]
E_des = 46000

lambda_ = h * c_0 / (E_des*eV_to_joule)
p2 = 4.2*10**(-6)
p0 = p1 = p2

Dn_3 = 3*p2**2/(2*lambda_) / 2
print(Dn_3)

z_g0 = 0.218
z_g1 = z_g0 + Dn_3
z_g2 = z_g0 + 2*Dn_3
z_detector = z_g2 + 0.01

h0 = 115e-6
h2 = 148e-6
h1 = 59e-6 

dc0 = [0.5, 0.5]
dc2 = [0.24, 0.52]

print("Z0: ", z_g0)
print("Z1: ", z_g1)
print("Z2: ", z_g2)
print("Z Detector: ", z_detector)

print(Dn_3)
# Out:
# 0.49085288108789216
# Z0:  0.218
# Z1:  0.7088528810878921
# Z2:  1.1997057621757843
# Z Detector:  1.2097057621757843
# 0.49085288108789216

# %%
2200/ 4200
# Out:
# 0.5238095238095238

# %%
N = 2**26
max_energy = 70000
dx = propagation.max_dx(z_g0, 10e-6, N, propagation.convert_energy_wavelength(max_energy))

# %% [markdown]
# # Now with both gratings modelled

# %%
meta_data_g0 = np.load('../grating_models/DRIE_models/mask_g0_different_dc_2.npz')
meta_data_g2 = np.load('../grating_models/DRIE_models/mask_g2_different_dc_2.npz')



grid_path_g0 = os.path.abspath('../grating_models/DRIE_models/mask_g0_different_dc_2.npy')
grid_path_g2 = os.path.abspath('../grating_models/DRIE_models/mask_g2_different_dc_2.npy')


dx_g0 = meta_data_g0['x'][1].item()-meta_data_g0['x'][0].item()
dz_g0 = meta_data_g0['z'].item()

dx_g2 = meta_data_g2['x'][1].item()-meta_data_g2['x'][0].item()
dz_g2 = meta_data_g2['z'].item()

# %%
s = spk.Spek(kvp=70, dk = 0.1, th = 10) # Create a spectrum
s.multi_filter((('Be', 0.15), ('Al', 3))) # Create a spectrum
k, f = s.get_spectrum(edges=True) # Get the spectrum

energyRange = [4000, 70000]
dE = 100
filtering = 0.000

energies = np.arange(5, 70+0.1, 0.1)*1e3


tube_spectrum_txt = interpolate.interp1d(k*1e3, f, fill_value = 'extrapolate')
spec_txt = tube_spectrum_txt(energies)

with h5py.File('../spectra/spectrum_70_spekpy_filtered_3mmAl.h5', 'w') as h5:
    h5.create_dataset('pdf', data =  spec_txt/ np.sum(spec_txt))
    h5.create_dataset('energy', data = energies)

path_to_spectrum = os.path.abspath('../spectra/spectrum_70_spekpy_filtered_3mmAl.h5')

# %%
config_dict = {
        "sim_params": {
            "N": N,
            "dx": dx,
            "z_detector": z_g2 + 370e-6,
            "detector_size": 0.004,
            "detector_pixel_size_x": 1e-7,
            "detector_pixel_size_y": 1.0,
            "chunk_size": 256 * 1024 * 1024 // 16,  # use 256MB chunks
        },
        "use_disk_vector": False,
        "save_final_u_vectors": False,
        "dtype": "c8",
        "multisource": {
            "type": "points",
            "energy_range": [11000, 70000],
            "x_range": [-10e-6, 10e-6],
            "z": 0.0,
            "nr_source_points": 1000,
            "seed": 1,
            "spectrum": path_to_spectrum,
        },
        "elements": [
            {
                "type": "sample",
                "z_start": z_g0,
                "pixel_size_x": dx_g0,
                "pixel_size_z": dz_g0,
                "grid_path": grid_path_g0,
                "materials": [["Au", 19.32], ["Si", 2.34]],
                "x_positions": [0.0],
            },
            {
                "type": "grating",
                "pitch": p0,
                "dc": [1.0, 1.0],
                "z_start": z_g0 + 117e-6,
                "thickness": 1e-8,
                "nr_steps": 0,
                "x_positions": [0.0],
                "substrate_thickness": 370*1e-6 - 117e-6 - 1e-8,
                "mat_a": ["Si", 2.34],
                "mat_b": ["Si", 2.34],
                "mat_substrate": ["Si", 2.34],
            },
            {
                "type": "grating",
                "pitch": p1,
                "dc": [0.5, 0.5],
                "z_start": z_g1,
                "thickness": h1,
                "nr_steps": 10,
                "x_positions": [0.0],
                "substrate_thickness": 200 * 1e-6 - h1,
                "mat_a": ["Si", 2.34],
                "mat_b": None,
                "mat_substrate": ["Si", 2.34],
            },
            {
                "type": "sample",
                "z_start": z_g2,
                "pixel_size_x": dx_g2,
                "pixel_size_z": dz_g2,
                "grid_path": grid_path_g2,
                "materials": [["Au", 19.32], ["Si", 2.34]],
                "x_positions": (np.arange(5) * p2/5).tolist(),
            },
            {
                "type": "grating",
                "pitch": p2,
                "dc": [1.0, 1.0],
                "z_start": z_g2 + 147e-6,
                "thickness": 1e-10,
                "nr_steps": 0,
                "x_positions": (np.arange(5) * p2/5).tolist(),
                "substrate_thickness": 370*1e-6 - 147e-6,
                "mat_a": ["Si", 2.34],
                "mat_b": ["Si", 2.34],
                "mat_substrate": ["Si", 2.34],
            },
        ],
}

sim_path = multisim.setup_simulation(config_dict, Path("."), simulations_dir)
# Out:
# 2024-03-24 21:03:32,260 INFO: Setting up simulation
# 2024-03-24 21:03:52,480 INFO: Finished setting up simulation in /scratch/vieirapa/XNPIG_Data/2024/03/20240324_210350719894

# %%
for i in range(1000):
    os.system(f"CUDA_VISIBLE_DEVICES=1 ../rave-sim/fast-wave/build-Release/fastwave -s {i} {sim_path}")
# Out:
# [2024-03-23 17:13:09.982] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20
[info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240323_171307718400/00000014
# [2024-03-23 17:39:15.176] [info] Simulating optical element 1/5
# [2024-03-23 17:39:27.398] [info] Elapsed time for optical element: 12218.872 ms
# [2024-03-23 17:39:27.398] [info] Simulating optical element 2/5
# [2024-03-23 17:39:27.450] [info] Elapsed time for optical element: 50.061314 ms
# [2024-03-23 17:39:27.498] [info] Simulating optical element 3/5
# [2024-03-23 17:39:28.119] [info] Elapsed time for optical element: 618.3548 ms
# [2024-03-23 17:39:28.172] [info] Simulating optical element 4/5
# [2024-03-23 17:39:47.220] [info] Elapsed time for optical element: 19045.246 ms
# [2024-03-23 17:39:47.220] [info] Simulating optical element 5/5
# [2024-03-23 17:39:47.303] [info] Elapsed time for optical element: 80.64784 ms
# [2024-03-23 17:39:47.306] [info] Running phase step 2/5
# [2024-03-23 17:39:47.310] [info] Simulating optical element 4/5
# [2024-03-23 17:40:07.249] [info] Elapsed time for optical element: 19936.053 ms
# [2024-03-23 17:40:07.249] [info] Simulating optical element 5/5
# [2024-03-23 17:40:07.332] [info] Elapsed time for optical element: 81.541504 ms
# [2024-03-23 17:40:07.336] [info] Running phase step 3/5
# [2024-03-23 17:40:07.340] [info] Simulating optical element 4/5
# [2024-03-23 17:40:27.254] [info] Elapsed time for optical element: 19911.545 ms
# [2024-03-23 17:40:27.254] [info] Simulating optical element 5/5
# [2024-03-23 17:40:27.338] [info] Elapsed time for optical element: 81.32723 ms
# [2024-03-23 17:40:27.341] [info] Running phase step 4/5
# [2024-03-23 17:40:27.345] [info] Simulating optical element 4/5
# [2024-03-23 17:40:47.235] [info] Elapsed time for optical element: 19887.908 ms
# [2024-03-23 17:40:47.235] [info] Simulating optical element 5/5
# [2024-03-23 17:40:47.319] [info] Elapsed time for optical element: 81.07213 ms
# [2024-03-23 17:40:47.322] [info] Running phase step 5/5
# [2024-03-23 17:40:47.322] [info] Simulating optical element 4/5
# [2024-03-23 17:41:07.207] [info] Elapsed time for optical element: 19884.973 ms
# [2024-03-23 17:41:07.207] [info] Simulating optical element 5/5
# [2024-03-23 17:41:07.290] [info] Elapsed time for optical element: 80.6064 ms
# [2024-03-23 17:41:07.294] [info] Simulation finished in 112.562440125 seconds
# [2024-03-23 17:41:07.729] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240323_171307718400/00000015
# [2024-03-23 17:41:08.170] [info] Simulating optical element 1/5
# [2024-03-23 17:41:20.473] [info] Elapsed time for optical element: 12300.828 ms
# [2024-03-23 17:41:20.473] [info] Simulating optical element 2/5
# [2024-03-23 17:41:20.526] [info] Elapsed time for optical element: 50.668865 ms
# [2024-03-23 17:41:20.575] [info] Simulating optical element 3/5
# [2024-03-23 17:41:21.218] [info] Elapsed time for optical element: 640.989 ms
# [2024-03-23 17:41:21.274] [info] Simulating optical element 4/5
# [2024-03-23 17:41:40.318] [info] Elapsed time for optical element: 19041.922 ms
# [2024-03-23 17:41:40.318] [info] Simulating optical element 5/5
# [2024-03-23 17:41:40.403] [info] Elapsed time for optical element: 81.840126 ms
# [2024-03-23 17:41:40.406] [info] Running phase step 2/5
# ...
# [2024-03-23 18:00:06.328] [info] Simulating optical element 2/5
# [2024-03-23 18:00:06.380] [info] Elapsed time for optical element: 49.990303 ms
# [2024-03-23 18:00:06.428] [info] Simulating optical element 3/5
# [2024-03-23 18:00:07.076] [info] Elapsed time for optical element: 645.1813 ms
# [2024-03-23 18:00:07.132] [info] Simulating optical element 4/5
# [2024-03-23 18:00:26.027] [info] Elapsed time for optical element: 18892.648 ms
# [2024-03-23 18:00:26.027] [info] Simulating optical element 5/5
# [2024-03-23 18:00:26.107] [info] Elapsed time for optical element: 78.11891 ms
# [2024-03-23 18:00:26.111] [info] Running phase step 2/5
# [2024-03-23 18:00:26.115] [info] Simulating optical element 4/5
# [2024-03-23 18:00:45.915] [info] Elapsed time for optical element: 19797.582 ms
# [2024-03-23 18:00:45.915] [info] Simulating optical element 5/5
# [2024-03-23 18:00:45.995] [info] Elapsed time for optical element: 77.82691 ms
# [2024-03-23 18:00:45.999] [info] Running phase step 3/5
# [2024-03-23 18:00:46.003] [info] Simulating optical element 4/5
# [2024-03-23 18:01:05.785] [info] Elapsed time for optical element: 19779.957 ms
# [2024-03-23 18:01:05.785] [info] Simulating optical element 5/5
# [2024-03-23 18:01:05.865] [info] Elapsed time for optical element: 77.66339 ms
# [2024-03-23 18:01:05.868] [info] Running phase step 4/5
# [2024-03-23 18:01:05.873] [info] Simulating optical element 4/5
# [2024-03-23 18:01:25.650] [info] Elapsed time for optical element: 19774.943 ms
# [2024-03-23 18:01:25.650] [info] Simulating optical element 5/5
# [2024-03-23 18:01:25.730] [info] Elapsed time for optical element: 77.83629 ms
# [2024-03-23 18:01:25.734] [info] Running phase step 5/5
# [2024-03-23 18:01:25.734] [info] Simulating optical element 4/5
# [2024-03-23 18:01:45.410] [info] Elapsed time for optical element: 19676.514 ms
# [2024-03-23 18:01:45.410] [info] Simulating optical element 5/5
# [2024-03-23 18:01:45.493] [info] Elapsed time for optical element: 80.8376 ms
# [2024-03-23 18:01:45.497] [info] Simulation finished in 111.832209662 seconds
# [2024-03-23 18:01:45.931] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240323_171307718400/00000026
# [2024-03-23 18:01:46.369] [info] Simulating optical element 1/5
# [2024-03-23 18:01:58.480] [info] Elapsed time for optical element: 12109.125 ms
# [2024-03-23 18:01:58.481] [info] Simulating optical element 2/5
# [2024-03-23 18:01:58.532] [info] Elapsed time for optical element: 49.555454 ms
# [2024-03-23 18:01:58.580] [info] Simulating optical element 3/5
# [2024-03-23 18:01:59.193] [info] Elapsed time for optical element: 610.8438 ms
# [2024-03-23 18:01:59.245] [info] Simulating optical element 4/5
# [2024-03-23 18:02:18.156] [info] Elapsed time for optical element: 18907.793 ms
# [2024-03-23 18:02:18.156] [info] Simulating optical element 5/5
# [2024-03-23 18:02:18.239] [info] Elapsed time for optical element: 80.79968 ms
# [2024-03-23 18:02:18.242] [info] Running phase step 2/5
# [2024-03-23 18:02:18.246] [info] Simulating optical element 4/5
# [2024-03-23 18:02:38.076] [info] Elapsed time for optical element: 19827.592 ms
# [2024-03-23 18:02:38.076] [info] Simulating optical element 5/5
# [2024-03-23 18:02:38.156] [info] Elapsed time for optical element: 77.83005 ms
# [2024-03-23 18:02:38.160] [info] Running phase step 3/5
# [2024-03-23 18:02:38.164] [info] Simulating optical element 4/5
# [2024-03-23 18:02:57.960] [info] Elapsed time for optical element: 19794.205 ms
# [2024-03-23 18:02:57.960] [info] Simulating optical element 5/5
# [2024-03-23 18:02:58.041] [info] Elapsed time for optical element: 77.761475 ms
# [2024-03-23 18:02:58.044] [info] Running phase step 4/5
# [2024-03-23 18:02:58.048] [info] Simulating optical element 4/5
# [2024-03-23 18:03:17.800] [info] Elapsed time for optical element: 19749.33 ms
# [2024-03-23 18:03:17.800] [info] Simulating optical element 5/5
# [2024-03-23 18:03:17.884] [info] Elapsed time for optical element: 81.69296 ms
# [2024-03-23 18:03:17.887] [info] Running phase step 5/5
# [2024-03-23 18:03:17.887] [info] Simulating optical element 4/5
# [2024-03-23 18:03:37.549] [info] Elapsed time for optical element: 19661.932 ms
# [2024-03-23 18:03:37.549] [info] Simulating optical element 5/5
# [2024-03-23 18:03:37.629] [info] Elapsed time for optical element: 77.627396 ms
# [2024-03-23 18:03:37.633] [info] Simulation finished in 111.701049268 seconds
# [2024-03-23 18:03:38.084] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240323_171307718400/00000027
# [2024-03-23 18:03:38.515] [info] Simulating optical element 1/5
# [2024-03-23 18:03:50.640] [info] Elapsed time for optical element: 12123.279 ms
# [2024-03-23 18:03:50.640] [info] Simulating optical element 2/5
# [2024-03-23 18:03:50.692] [info] Elapsed time for optical element: 49.50813 ms
# [2024-03-23 18:03:50.740] [info] Simulating optical element 3/5
# [2024-03-23 18:03:51.351] [info] Elapsed time for optical element: 609.3086 ms
# [2024-03-23 18:03:51.404] [info] Simulating optical element 4/5
# [2024-03-23 18:04:10.343] [info] Elapsed time for optical element: 18936.1 ms
# [2024-03-23 18:04:10.343] [info] Simulating optical element 5/5
# [2024-03-23 18:04:10.426] [info] Elapsed time for optical element: 81.19706 ms
# [2024-03-23 18:04:10.430] [info] Running phase step 2/5
# [2024-03-23 18:04:10.434] [info] Simulating optical element 4/5
# [2024-03-23 18:04:30.235] [info] Elapsed time for optical element: 19799.52 ms
# [2024-03-23 18:04:30.236] [info] Simulating optical element 5/5
# [2024-03-23 18:04:30.319] [info] Elapsed time for optical element: 81.35405 ms
# [2024-03-23 18:04:30.323] [info] Running phase step 3/5
# [2024-03-23 18:04:30.327] [info] Simulating optical element 4/5
# [2024-03-23 18:04:50.111] [info] Elapsed time for optical element: 19781.982 ms
# [2024-03-23 18:04:50.111] [info] Simulating optical element 5/5
# [2024-03-23 18:04:50.191] [info] Elapsed time for optical element: 77.8648 ms
# [2024-03-23 18:04:50.195] [info] Running phase step 4/5
# [2024-03-23 18:04:50.199] [info] Simulating optical element 4/5
# [2024-03-23 18:05:09.985] [info] Elapsed time for optical element: 19783.732 ms
# [2024-03-23 18:05:09.985] [info] Simulating optical element 5/5
# [2024-03-23 18:05:10.065] [info] Elapsed time for optical element: 77.92323 ms
# [2024-03-23 18:05:10.069] [info] Running phase step 5/5
# [2024-03-23 18:05:10.069] [info] Simulating optical element 4/5
# [2024-03-23 18:05:29.727] [info] Elapsed time for optical element: 19658.137 ms
# [2024-03-23 18:05:29.727] [info] Simulating optical element 5/5
# [2024-03-23 18:05:29.810] [info] Elapsed time for optical element: 81.45351 ms
# [2024-03-23 18:05:29.815] [info] Simulation finished in 111.729804376 seconds
# [2024-03-23 18:05:30.265] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240323_171307718400/00000028
# [2024-03-23 18:05:30.709] [info] Simulating optical element 1/5
# [2024-03-23 18:05:42.866] [info] Elapsed time for optical element: 12155.011 ms
# [2024-03-23 18:05:42.866] [info] Simulating optical element 2/5
# [2024-03-23 18:05:42.918] [info] Elapsed time for optical element: 49.68272 ms
# [2024-03-23 18:05:42.966] [info] Simulating optical element 3/5
# [2024-03-23 18:05:43.587] [info] Elapsed time for optical element: 618.65533 ms
# [2024-03-23 18:05:43.640] [info] Simulating optical element 4/5
# [2024-03-23 18:06:02.598] [info] Elapsed time for optical element: 18956.252 ms
# [2024-03-23 18:06:02.599] [info] Simulating optical element 5/5
# [2024-03-23 18:06:02.682] [info] Elapsed time for optical element: 81.43427 ms
# [2024-03-23 18:06:02.686] [info] Running phase step 2/5
# [2024-03-23 18:06:02.690] [info] Simulating optical element 4/5
# [2024-03-23 18:06:22.511] [info] Elapsed time for optical element: 19818.72 ms
# [2024-03-23 18:06:22.511] [info] Simulating optical element 5/5
# [2024-03-23 18:06:22.595] [info] Elapsed time for optical element: 81.39571 ms
# [2024-03-23 18:06:22.598] [info] Running phase step 3/5
# [2024-03-23 18:06:22.602] [info] Simulating optical element 4/5
# [2024-03-23 18:06:42.384] [info] Elapsed time for optical element: 19779.688 ms
# [2024-03-23 18:06:42.384] [info] Simulating optical element 5/5
# [2024-03-23 18:06:42.468] [info] Elapsed time for optical element: 81.7968 ms
# [2024-03-23 18:06:42.472] [info] Running phase step 4/5
# [2024-03-23 18:06:42.476] [info] Simulating optical element 4/5
# [2024-03-23 18:07:02.237] [info] Elapsed time for optical element: 19759.105 ms
# [2024-03-23 18:07:02.237] [info] Simulating optical element 5/5
# [2024-03-23 18:07:02.321] [info] Elapsed time for optical element: 80.795135 ms
# [2024-03-23 18:07:02.324] [info] Running phase step 5/5
# [2024-03-23 18:07:02.324] [info] Simulating optical element 4/5
# [2024-03-23 18:07:22.013] [info] Elapsed time for optical element: 19689.428 ms
# [2024-03-23 18:07:22.013] [info] Simulating optical element 5/5
# [2024-03-23 18:07:22.096] [info] Elapsed time for optical element: 80.689156 ms
# [2024-03-23 18:07:22.100] [info] Simulation finished in 111.834465137 seconds
# [2024-03-23 18:07:22.541] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240323_171307718400/00000029
# [2024-03-23 18:07:22.981] [info] Simulating optical element 1/5
# [2024-03-23 18:07:35.226] [info] Elapsed time for optical element: 12242.52 ms
# [2024-03-23 18:07:35.226] [info] Simulating optical element 2/5
# [2024-03-23 18:07:35.279] [info] Elapsed time for optical element: 50.103905 ms
# [2024-03-23 18:07:35.327] [info] Simulating optical element 3/5
# [2024-03-23 18:07:35.970] [info] Elapsed time for optical element: 641.3513 ms
# [2024-03-23 18:07:36.027] [info] Simulating optical element 4/5
# [2024-03-23 18:07:54.960] [info] Elapsed time for optical element: 18931.156 ms
# [2024-03-23 18:07:54.960] [info] Simulating optical element 5/5
# [2024-03-23 18:07:55.041] [info] Elapsed time for optical element: 77.840034 ms
# [2024-03-23 18:07:55.044] [info] Running phase step 2/5
# [2024-03-23 18:07:55.048] [info] Simulating optical element 4/5
# [2024-03-23 18:08:14.867] [info] Elapsed time for optical element: 19816.465 ms
# [2024-03-23 18:08:14.867] [info] Simulating optical element 5/5
# [2024-03-23 18:08:14.951] [info] Elapsed time for optical element: 81.68448 ms
# [2024-03-23 18:08:14.954] [info] Running phase step 3/5
# [2024-03-23 18:08:14.959] [info] Simulating optical element 4/5
# [2024-03-23 18:08:34.753] [info] Elapsed time for optical element: 19791.873 ms
# [2024-03-23 18:08:34.753] [info] Simulating optical element 5/5
# [2024-03-23 18:08:34.836] [info] Elapsed time for optical element: 80.83827 ms
# [2024-03-23 18:08:34.839] [info] Running phase step 4/5
# [2024-03-23 18:08:34.844] [info] Simulating optical element 4/5
# [2024-03-23 18:08:54.623] [info] Elapsed time for optical element: 19777.453 ms
# [2024-03-23 18:08:54.623] [info] Simulating optical element 5/5
# [2024-03-23 18:08:54.704] [info] Elapsed time for optical element: 77.88055 ms
# [2024-03-23 18:08:54.707] [info] Running phase step 5/5
# [2024-03-23 18:08:54.707] [info] Simulating optical element 4/5
# [2024-03-23 18:09:14.389] [info] Elapsed time for optical element: 19682.012 ms
# [2024-03-23 18:09:14.389] [info] Simulating optical element 5/5
# [2024-03-23 18:09:14.469] [info] Elapsed time for optical element: 78.21517 ms
# [2024-03-23 18:09:14.473] [info] Simulation finished in 111.931255014 seconds
# [2024-03-23 18:09:14.908] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240323_171307718400/00000030
# [2024-03-23 18:09:15.351] [info] Simulating optical element 1/5
# [2024-03-23 18:09:27.494] [info] Elapsed time for optical element: 12140.386 ms
# [2024-03-23 18:09:27.494] [info] Simulating optical element 2/5
# [2024-03-23 18:09:27.546] [info] Elapsed time for optical element: 49.64304 ms
# [2024-03-23 18:09:27.593] [info] Simulating optical element 3/5
# [2024-03-23 18:09:28.211] [info] Elapsed time for optical element: 615.34656 ms
# [2024-03-23 18:09:28.264] [info] Simulating optical element 4/5
# [2024-03-23 18:09:47.204] [info] Elapsed time for optical element: 18937.99 ms
# [2024-03-23 18:09:47.204] [info] Simulating optical element 5/5
# [2024-03-23 18:09:47.284] [info] Elapsed time for optical element: 77.90288 ms
# [2024-03-23 18:09:47.288] [info] Running phase step 2/5
# [2024-03-23 18:09:47.292] [info] Simulating optical element 4/5
# [2024-03-23 18:10:07.117] [info] Elapsed time for optical element: 19822.447 ms
# [2024-03-23 18:10:07.117] [info] Simulating optical element 5/5
# [2024-03-23 18:10:07.200] [info] Elapsed time for optical element: 80.87142 ms
# [2024-03-23 18:10:07.203] [info] Running phase step 3/5
# [2024-03-23 18:10:07.207] [info] Simulating optical element 4/5
# [2024-03-23 18:10:27.003] [info] Elapsed time for optical element: 19793.133 ms
# [2024-03-23 18:10:27.003] [info] Simulating optical element 5/5
# [2024-03-23 18:10:27.083] [info] Elapsed time for optical element: 77.98448 ms
# [2024-03-23 18:10:27.087] [info] Running phase step 4/5
# [2024-03-23 18:10:27.091] [info] Simulating optical element 4/5
# [2024-03-23 18:10:46.879] [info] Elapsed time for optical element: 19785.928 ms
# [2024-03-23 18:10:46.879] [info] Simulating optical element 5/5
# [2024-03-23 18:10:46.959] [info] Elapsed time for optical element: 77.96765 ms
# [2024-03-23 18:10:46.963] [info] Running phase step 5/5
# [2024-03-23 18:10:46.963] [info] Simulating optical element 4/5
# [2024-03-23 18:11:06.662] [info] Elapsed time for optical element: 19699.254 ms
# [2024-03-23 18:11:06.662] [info] Simulating optical element 5/5
# [2024-03-23 18:11:06.746] [info] Elapsed time for optical element: 81.22368 ms
# [2024-03-23 18:11:06.750] [info] Simulation finished in 111.840842286 seconds
# [2024-03-23 18:11:07.181] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240323_171307718400/00000031
# [2024-03-23 18:11:07.622] [info] Simulating optical element 1/5
# [2024-03-23 18:11:19.812] [info] Elapsed time for optical element: 12187.752 ms
# [2024-03-23 18:11:19.812] [info] Simulating optical element 2/5
# [2024-03-23 18:11:19.864] [info] Elapsed time for optical element: 49.994175 ms
# [2024-03-23 18:11:19.912] [info] Simulating optical element 3/5
# [2024-03-23 18:11:20.538] [info] Elapsed time for optical element: 623.44635 ms
# [2024-03-23 18:11:20.591] [info] Simulating optical element 4/5
# [2024-03-23 18:11:39.564] [info] Elapsed time for optical element: 18970.678 ms
# [2024-03-23 18:11:39.564] [info] Simulating optical element 5/5
# [2024-03-23 18:11:39.648] [info] Elapsed time for optical element: 81.47353 ms
# [2024-03-23 18:11:39.651] [info] Running phase step 2/5
# [2024-03-23 18:11:39.655] [info] Simulating optical element 4/5
# [2024-03-23 18:11:59.493] [info] Elapsed time for optical element: 19835.68 ms
# [2024-03-23 18:11:59.493] [info] Simulating optical element 5/5
# [2024-03-23 18:11:59.573] [info] Elapsed time for optical element: 77.91616 ms
# [2024-03-23 18:11:59.577] [info] Running phase step 3/5
# [2024-03-23 18:11:59.581] [info] Simulating optical element 4/5
# [2024-03-23 18:12:19.405] [info] Elapsed time for optical element: 19822.033 ms
# [2024-03-23 18:12:19.405] [info] Simulating optical element 5/5
# [2024-03-23 18:12:19.486] [info] Elapsed time for optical element: 78.17664 ms
# [2024-03-23 18:12:19.489] [info] Running phase step 4/5
# [2024-03-23 18:12:19.493] [info] Simulating optical element 4/5
# [2024-03-23 18:12:39.282] [info] Elapsed time for optical element: 19786.049 ms
# [2024-03-23 18:12:39.282] [info] Simulating optical element 5/5
# [2024-03-23 18:12:39.366] [info] Elapsed time for optical element: 81.90445 ms
# [2024-03-23 18:12:39.369] [info] Running phase step 5/5
# [2024-03-23 18:12:39.369] [info] Simulating optical element 4/5
# [2024-03-23 18:12:59.051] [info] Elapsed time for optical element: 19681.846 ms
# [2024-03-23 18:12:59.051] [info] Simulating optical element 5/5
# [2024-03-23 18:12:59.132] [info] Elapsed time for optical element: 78.215805 ms
# [2024-03-23 18:12:59.136] [info] Simulation finished in 111.953873712 seconds
# [2024-03-23 18:12:59.572] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240323_171307718400/00000032
# [2024-03-23 18:13:00.018] [info] Simulating optical element 1/5
