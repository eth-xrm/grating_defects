# %%
# Copyright (c) 2025, ETH Zurich

# %%
import sys
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import os
import scipy.stats as stats
import scipy.ndimage
from tqdm import tqdm
import spekpy as spk
import h5py

from scipy import interpolate

# %%
rave_sim_dir = Path('../rave-sim').resolve()
simulations_dir = Path('<PATH_TO_STORE_SIMULATIONS>')
scratch_dir = simulations_dir


sys.path.insert(0, str(rave_sim_dir / "nist_lookup"))
from nist_lookup.xraydb_plugin import xray_delta_beta

# %%
sys.path.insert(0, str(rave_sim_dir / "big-wave"))
import multisim
import config
import util
import propagation

# %%
def calculate_G1_height(eng):
    # constants
    h = 6.62607004 * 10**(-34) # planck constant in mˆ2 kg / s
    c_0 = 299792458 # speed of light in m / s
    eV_to_joule = 1.602176634*10**(-19)
    N_A = 6.02214086 * 10**23 #[1/mol]
    
    lambda_ = h * c_0 / (eng*eV_to_joule)
    delta_diff = xray_delta_beta('Si', 2.34, eng)[0]
    height = np.pi  * lambda_ / (2*np.pi * delta_diff)

    return height


def signal_retrieval_least_squares(data, period=None, axis=-1):
    if axis != -1:
        data = np.moveaxis(data, axis, -1)

    nsteps = data.shape[-1]

    if period is None:
        period = nsteps

    phi = np.linspace(0, 2 * np.pi * nsteps / (period), nsteps, endpoint=False)
    M = np.c_[np.sin(phi), np.cos(phi), np.ones(nsteps)]
    res, chi2, _rank, _sing_vals = np.linalg.lstsq(M, data.reshape((-1, nsteps)).T, rcond=-1)

    res = res.T.reshape((*data.shape[:-1], -1))

    dabs = res[...,2]
    dphase = -np.arctan2(res[...,0], res[...,1])
    dvis = np.sqrt(res[...,0]**2 + res[...,1]**2) / dabs

    # normalization to the total number of counts
    dabs *= nsteps

    return dabs, dphase, dvis, np.nanmean(chi2)


def calculate_pixel_intensity(x, fringe, pxEdges, statistics = 'sum'):
    fringeStats = stats.binned_statistic(x, fringe, bins=pxEdges, statistic = statistics)
    return fringeStats.statistic

def perform_binned_signal_retrieval(x, wf, pxSize, nrSteps, plot_curve = True):
    leftSide = np.arange(0-pxSize/2, np.min(x), -pxSize)
    rightSide = np.arange(0 + pxSize/2, np.max(x), pxSize)
    pxEdges = np.concatenate([np.flip(leftSide), rightSide])
    int_px = []
    for i in range(nrSteps):
        int_px.append(calculate_pixel_intensity(x, wf[i,:], pxEdges))
    int_px = np.asarray(int_px)

    trans, phase, vis, _ = signal_retrieval_least_squares(int_px, period = nrSteps, axis = 0)
    if plot_curve:
        plot_curves(trans, phase, vis, pxEdges)
    return int_px, trans, phase, vis, pxEdges

def plot_curves(trans, phase, vis, pxEdges):

    fig, axs = plt.subplots(figsize=(15,6), sharex = True, nrows = 1, ncols = 2)
    axs[0].plot(pxEdges[1:], trans, label = 'Transmission')
    axs[0].set_title('Transmission')
    axs[1].plot(pxEdges[1:], vis, label = 'Visibility')
    axs[1].set_title('Visibility')

def perform_binning(x, wf, pxSize):
    leftSide = np.arange(0-pxSize/2, np.min(x), -pxSize)
    rightSide = np.arange(0 + pxSize/2, np.max(x), pxSize)
    pxEdges = np.concatenate([np.flip(leftSide), rightSide])
    int_px = calculate_pixel_intensity(x, wf, pxEdges, statistics = 'mean')
    return int_px


    #np.random.seed(1)
    
    sample_energy = np.random.choice(x, p=y)
    if sample_energy >= low_threshold:
        return True
    else:
        return False
    
    
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

def calculate_SNR(wavefronts, detector_x, phase_steps):
    summed_wf = np.zeros_like(wavefronts[0][0])
        
    for point in wavefronts:
        wf, x_point, eng = point
        
        summed_wf += wf

    return summed_wf

def get_subdict(dict_, idx):
    sub_dict = {}
    for key in dict_.keys():
        sub_dict[key] = dict_[key][idx]
    return sub_dict

def calc_Vis_theoretical(eng, Edes,m):
    V = 2/np.pi * np.abs(np.sin(np.pi / 2 * Edes / eng)**2 * np.sin(m * np.pi / 2 * Edes / eng))
    return V

def mu_h2o(eng):
    lambda_ = h * c_0 / (eng*eV_to_joule)
    beta = xray_delta_beta('H2O', 1.0, eng)[1]
    return 4 * np.pi / lambda_ * beta

def mu_al(eng):
    lambda_ = h * c_0 / (eng*eV_to_joule)
    beta = xray_delta_beta('Al', 2.7, eng)[1]
    return 4 * np.pi / lambda_ * beta

# %%
# constants
h = 6.62607004 * 10**(-34) # planck constant in mˆ2 kg / s
c_0 = 299792458 # speed of light in m / s
eV_to_joule = 1.602176634*10**(-19)
N_A = 6.02214086 * 10**23 #[1/mol]
E_des = 46000

lambda_ = h * c_0 / (E_des*eV_to_joule)
p2 = 4.2*10**(-6)
p0 = p1 = p2

Dn_3 = 3*p2**2/(2*lambda_) / 2
print(Dn_3)

z_g0 = 0.218
z_g1 = z_g0 + Dn_3
z_g2 = z_g0 + 2*Dn_3
z_detector = z_g2 + 0.01

h0 = 115e-6
h2 = 148e-6
h1 = 59e-6 

dc0 = [0.5, 0.5]
dc2 = [0.24, 0.52]

print("Z0: ", z_g0)
print("Z1: ", z_g1)
print("Z2: ", z_g2)
print("Z Detector: ", z_detector)

print(Dn_3)
# Out:
# 0.49085288108789216
# Z0:  0.218
# Z1:  0.7088528810878921
# Z2:  1.1997057621757843
# Z Detector:  1.2097057621757843
# 0.49085288108789216

# %%
2200/ 4200
# Out:
# 0.5238095238095238

# %%
N = 2**26
max_energy = 70000
dx = propagation.max_dx(z_g0, 10e-6, N, propagation.convert_energy_wavelength(max_energy))

# %%
dx
# Out:
# 2.3865140974521635e-10

# %% [markdown]
# # Now with both gratings modelled

# %%
meta_data_g0 = np.load('../grating_models/DRIE_models/mask_g0_different_dc_2.npz')
meta_data_g2 = np.load('../grating_models/DRIE_models/mask_g2_different_dc_2.npz')



grid_path_g0 = os.path.abspath('../grating_models/DRIE_models/mask_g0_different_dc_2.npy')
grid_path_g2 = os.path.abspath('../grating_models/DRIE_models/mask_g2_different_dc_2.npy')


dx_g0 = meta_data_g0['x'][1].item()-meta_data_g0['x'][0].item()
dz_g0 = meta_data_g0['z'].item()

dx_g2 = meta_data_g2['x'][1].item()-meta_data_g2['x'][0].item()
dz_g2 = meta_data_g2['z'].item()

# %%
s = spk.Spek(kvp=70, dk = 0.1, th = 10) # Create a spectrum

s.filter('Be', 0.15) # Create a spectrum
k, f = s.get_spectrum(edges=True) # Get the spectrum

energyRange = [4000, 70000]
dE = 100
filtering = 0.000

energies = np.arange(5, 70+0.1, 0.1)*1e3


tube_spectrum_txt = interpolate.interp1d(k*1e3, f, fill_value = 'extrapolate')
spec_txt = tube_spectrum_txt(energies)

with h5py.File('../spectra/spectrum_70_spekpy_unfiltered.h5', 'w') as h5:
    h5.create_dataset('pdf', data =  spec_txt/ np.sum(spec_txt))
    h5.create_dataset('energy', data = energies) 

path_to_spectrum = os.path.abspath('../spectra/spectrum_70_spekpy_unfiltered.h5')

# %%
config_dict = {
        "sim_params": {
            "N": N,
            "dx": dx,
            "z_detector": z_g2 + 370e-6,
            "detector_size": 0.004,
            "detector_pixel_size_x": 1e-7,
            "detector_pixel_size_y": 1.0,
            "chunk_size": 256 * 1024 * 1024 // 16,  # use 256MB chunks
        },
        "use_disk_vector": False,
        "save_final_u_vectors": False,
        "dtype": "c8",
        "multisource": {
            "type": "points",
            "energy_range": [11000, 70000],
            "x_range": [-10e-6, 10e-6],
            "z": 0.0,
            "nr_source_points": 1000,
            "seed": 1,
            "spectrum": path_to_spectrum,
        },
        "elements": [
            {
                "type": "sample",
                "z_start": z_g0,
                "pixel_size_x": dx_g0,
                "pixel_size_z": dz_g0,
                "grid_path": grid_path_g0,
                "materials": [["Au", 19.32], ["Si", 2.34]],
                "x_positions": [0.0],
            },
            {
                "type": "grating",
                "pitch": p0,
                "dc": [1.0, 1.0],
                "z_start": z_g0 + 117e-6,
                "thickness": 1e-8,
                "nr_steps": 0,
                "x_positions": [0.0],
                "substrate_thickness": 370*1e-6 - 117e-6 - 1e-8,
                "mat_a": ["Si", 2.34],
                "mat_b": ["Si", 2.34],
                "mat_substrate": ["Si", 2.34],
            },
            {
                "type": "grating",
                "pitch": p1,
                "dc": [0.5, 0.5],
                "z_start": z_g1,
                "thickness": h1,
                "nr_steps": 10,
                "x_positions": [0.0],
                "substrate_thickness": 200 * 1e-6 - h1,
                "mat_a": ["Si", 2.34],
                "mat_b": None,
                "mat_substrate": ["Si", 2.34],
            },
            {
                "type": "sample",
                "z_start": z_g2,
                "pixel_size_x": dx_g2,
                "pixel_size_z": dz_g2,
                "grid_path": grid_path_g2,
                "materials": [["Au", 19.32], ["Si", 2.34]],
                "x_positions": (np.arange(5) * p2/5).tolist(),
            },
            {
                "type": "grating",
                "pitch": p2,
                "dc": [1.0, 1.0],
                "z_start": z_g2 + 147e-6,
                "thickness": 1e-10,
                "nr_steps": 0,
                "x_positions": (np.arange(5) * p2/5).tolist(),
                "substrate_thickness": 370*1e-6 - 147e-6,
                "mat_a": ["Si", 2.34],
                "mat_b": ["Si", 2.34],
                "mat_substrate": ["Si", 2.34],
            },
        ],
}

sim_path = multisim.setup_simulation(config_dict, Path("."), simulations_dir)
# Out:
# 2024-03-24 20:21:43,405 INFO: Setting up simulation
# 2024-03-24 20:22:04,109 INFO: Finished setting up simulation in /scratch/vieirapa/XNPIG_Data/2024/03/20240324_202202403039

# %%
for i in range(1000):
    os.system(f"CUDA_VISIBLE_DEVICES=0 ../rave-sim/fast-wave/build-Release/fastwave -s {i} {sim_path}")
# Out:
# [2024-03-24 20:23:19.946] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240324_202202403039/00000000
# [2024-03-24 20:23:20.293] [info] Simulating optical element 1/5
# [2024-03-24 20:23:25.589] [info] Elapsed time for optical element: 5296.235 ms
# [2024-03-24 20:23:25.589] [info] Simulating optical element 2/5
# [2024-03-24 20:23:25.612] [info] Elapsed time for optical element: 23.04512 ms
# [2024-03-24 20:23:25.633] [info] Simulating optical element 3/5
# [2024-03-24 20:23:25.906] [info] Elapsed time for optical element: 272.3738 ms
# [2024-03-24 20:23:25.929] [info] Simulating optical element 4/5
# [2024-03-24 20:23:34.426] [info] Elapsed time for optical element: 8497.233 ms
# [2024-03-24 20:23:34.426] [info] Simulating optical element 5/5
# [2024-03-24 20:23:34.462] [info] Elapsed time for optical element: 35.73104 ms
# [2024-03-24 20:23:34.463] [info] Running phase step 2/5
# [2024-03-24 20:23:34.465] [info] Simulating optical element 4/5
# [2024-03-24 20:23:42.963] [info] Elapsed time for optical element: 8497.636 ms
# [2024-03-24 20:23:42.963] [info] Simulating optical element 5/5
# [2024-03-24 20:23:42.999] [info] Elapsed time for optical element: 35.737408 ms
# [2024-03-24 20:23:43.000] [info] Running phase step 3/5
# [2024-03-24 20:23:43.002] [info] Simulating optical element 4/5
# [2024-03-24 20:23:51.498] [info] Elapsed time for optical element: 8495.957 ms
# [2024-03-24 20:23:51.498] [info] Simulating optical element 5/5
# [2024-03-24 20:23:51.533] [info] Elapsed time for optical element: 35.7448 ms
# [2024-03-24 20:23:51.535] [info] Running phase step 4/5
# [2024-03-24 20:23:51.537] [info] Simulating optical element 4/5
# [2024-03-24 20:24:00.047] [info] Elapsed time for optical element: 8510.324 ms
# [2024-03-24 20:24:00.047] [info] Simulating optical element 5/5
# [2024-03-24 20:24:00.083] [info] Elapsed time for optical element: 35.71072 ms
# [2024-03-24 20:24:00.084] [info] Running phase step 5/5
# [2024-03-24 20:24:00.084] [info] Simulating optical element 4/5
# [2024-03-24 20:24:08.612] [info] Elapsed time for optical element: 8527.928 ms
# [2024-03-24 20:24:08.612] [info] Simulating optical element 5/5
# [2024-03-24 20:24:08.647] [info] Elapsed time for optical element: 35.715263 ms
# [2024-03-24 20:24:08.649] [info] Simulation finished in 48.70243571 seconds
# [2024-03-24 20:24:09.073] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20
# [2024-03-24 20:28:58.881] [info] Elapsed time for optical element: 9533.577 ms
# [2024-03-24 20:28:58.881] [info] Simulating optical element 5/5
# [2024-03-24 20:28:58.920] [info] Elapsed time for optical element: 38.995457 ms
# [2024-03-24 20:28:58.921] [info] Running phase step 3/5
# [2024-03-24 20:28:58.923] [info] Simulating optical element 4/5
# [2024-03-24 20:29:08.468] [info] Elapsed time for optical element: 9545.323 ms
# [2024-03-24 20:29:08.469] [info] Simulating optical element 5/5
# [2024-03-24 20:29:08.509] [info] Elapsed time for optical element: 40.06227 ms
# [2024-03-24 20:29:08.510] [info] Running phase step 4/5
# [2024-03-24 20:29:08.512] [info] Simulating optical element 4/5
# [2024-03-24 20:29:18.067] [info] Elapsed time for optical element: 9555.756 ms
# [2024-03-24 20:29:18.067] [info] Simulating optical element 5/5
# [2024-03-24 20:29:18.107] [info] Elapsed time for optical element: 39.411488 ms
# [2024-03-24 20:29:18.108] [info] Running phase step 5/5
# [2024-03-24 20:29:18.108] [info] Simulating optical element 4/5
# [2024-03-24 20:29:27.646] [info] Elapsed time for optical element: 9537.876 ms
# [2024-03-24 20:29:27.646] [info] Simulating optical element 5/5
# [2024-03-24 20:29:27.684] [info] Elapsed time for optical element: 37.910526 ms
# [2024-03-24 20:29:27.686] [info] Simulation finished in 54.446429247 seconds
# [2024-03-24 20:29:28.147] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240324_202202403039/00000007
# [2024-03-24 20:29:28.532] [info] Simulating optical element 1/5
# [2024-03-24 20:29:34.415] [info] Elapsed time for optical element: 5883.583 ms
# [2024-03-24 20:29:34.415] [info] Simulating optical element 2/5
# [2024-03-24 20:29:34.439] [info] Elapsed time for optical element: 23.543585 ms
# [2024-03-24 20:29:34.460] [info] Simulating optical element 3/5
# [2024-03-24 20:29:34.751] [info] Elapsed time for optical element: 290.7259 ms
# [2024-03-24 20:29:34.776] [info] Simulating optical element 4/5
# [2024-03-24 20:29:44.379] [info] Elapsed time for optical element: 9603.191 ms
# [2024-03-24 20:29:44.379] [info] Simulating optical element 5/5
# [2024-03-24 20:29:44.417] [info] Elapsed time for optical element: 38.06003 ms
# [2024-03-24 20:29:44.418] [info] Running phase step 2/5
# [2024-03-24 20:29:44.420] [info] Simulating optical element 4/5
# [2024-03-24 20:29:53.956] [info] Elapsed time for optical element: 9535.714 ms
# [2024-03-24 20:29:53.956] [info] Simulating optical element 5/5
# [2024-03-24 20:29:53.995] [info] Elapsed time for optical element: 38.772736 ms
# [2024-03-24 20:29:53.996] [info] Running phase step 3/5
# [2024-03-24 20:29:53.998] [info] Simulating optical element 4/5
# [2024-03-24 20:30:03.534] [info] Elapsed time for optical element: 9536.022 ms
# [2024-03-24 20:30:03.534] [info] Simulating optical element 5/5
# [2024-03-24 20:30:03.572] [info] Elapsed time for optical element: 37.67744 ms
# [2024-03-24 20:30:03.573] [info] Running phase step 4/5
# [2024-03-24 20:30:03.575] [info] Simulating optical element 4/5
# [2024-03-24 20:30:13.110] [info] Elapsed time for optical element: 9534.942 ms
# [2024-03-24 20:30:13.110] [info] Simulating optical element 5/5
# [2024-03-24 20:30:13.148] [info] Elapsed time for optical element: 38.433792 ms
# [2024-03-24 20:30:13.149] [info] Running phase step 5/5
# [2024-03-24 20:30:13.149] [info] Simulating optical element 4/5
# [2024-03-24 20:30:22.665] [info] Elapsed time for optical element: 9516.11 ms
# [2024-03-24 20:30:22.665] [info] Simulating optical element 5/5
# [2024-03-24 20:30:22.704] [info] Elapsed time for optical element: 38.488033 ms
# [2024-03-24 20:30:22.706] [info] Simulation finished in 54.558092273 seconds
# [2024-03-24 20:30:23.146] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240324_202202403039/00000008
# [2024-03-24 20:30:23.502] [info] Simulating optical element 1/5
# [2024-03-24 20:30:29.344] [info] Elapsed time for optical element: 5841.567 ms
# [2024-03-24 20:30:29.344] [info] Simulating optical element 2/5
# [2024-03-24 20:30:29.367] [info] Elapsed time for optical element: 23.612928 ms
# [2024-03-24 20:30:29.389] [info] Simulating optical element 3/5
# [2024-03-24 20:30:29.676] [info] Elapsed time for optical element: 287.4326 ms
# [2024-03-24 20:30:29.701] [info] Simulating optical element 4/5
# [2024-03-24 20:30:39.204] [info] Elapsed time for optical element: 9503.548 ms
# [2024-03-24 20:30:39.204] [info] Simulating optical element 5/5
# [2024-03-24 20:30:39.242] [info] Elapsed time for optical element: 38.186623 ms
# [2024-03-24 20:30:39.244] [info] Running phase step 2/5
# [2024-03-24 20:30:39.245] [info] Simulating optical element 4/5
# [2024-03-24 20:30:48.749] [info] Elapsed time for optical element: 9503.903 ms
# [2024-03-24 20:30:48.749] [info] Simulating optical element 5/5
# [2024-03-24 20:30:48.789] [info] Elapsed time for optical element: 39.355778 ms
# [2024-03-24 20:30:48.790] [info] Running phase step 3/5
# [2024-03-24 20:30:48.792] [info] Simulating optical element 4/5
# [2024-03-24 20:30:58.301] [info] Elapsed time for optical element: 9509.316 ms
# [2024-03-24 20:30:58.301] [info] Simulating optical element 5/5
# [2024-03-24 20:30:58.340] [info] Elapsed time for optical element: 38.943615 ms
# [2024-03-24 20:30:58.341] [info] Running phase step 4/5
# [2024-03-24 20:30:58.343] [info] Simulating optical element 4/5
# [2024-03-24 20:31:07.827] [info] Elapsed time for optical element: 9483.7295 ms
# [2024-03-24 20:31:07.827] [info] Simulating optical element 5/5
# [2024-03-24 20:31:07.866] [info] Elapsed time for optical element: 38.71968 ms
# [2024-03-24 20:31:07.867] [info] Running phase step 5/5
# [2024-03-24 20:31:07.867] [info] Simulating optical element 4/5
# [2024-03-24 20:31:17.358] [info] Elapsed time for optical element: 9491.4795 ms
# [2024-03-24 20:31:17.358] [info] Simulating optical element 5/5
# [2024-03-24 20:31:17.396] [info] Elapsed time for optical element: 37.689632 ms
# [2024-03-24 20:31:17.398] [info] Simulation finished in 54.25073774 seconds
# [2024-03-24 20:31:17.841] [info] Running simulation /scratch/vieirapa/XNPIG_Data/2024/03/20240324_202202403039/00000009
# [2024-03-24 20:31:18.172] [info] Simulating optical element 1/5
